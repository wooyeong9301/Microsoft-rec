# %% [markdown]
# # Bilateral Variational Autoencoder
# **BiVAE**에 관한 논문은 WSDM'21 컨퍼런스에서 처음 발표되었습니다.
# 모델의 시행은 Cornac으로부터 이루어지며, Cornac은 보조적인 데이터를 활용하는 모델들에 집중한 멀티모달 추천 시스템을 위한 프레임워크입니다.

# %%
import sys
import os
import torch
import cornac
import papermill as pm
import scrapbook as sb
import pandas as pd
from recommenders.datasets import movielens
from recommenders.datasets.python_splitters import python_random_split
from recommenders.evaluation.python_evaluation import map_at_k, ndcg_at_k, precision_at_k, recall_at_k
from recommenders.models.cornac.cornac_utils import predict_ranking
from recommenders.utils.timer import Timer
from recommenders.utils.constants import SEED

print("System version: {}".format(sys.version))
print("PyTorch version: {}".format(torch.__version__))
print("Cornac version: {}".format(cornac.__version__))
# Out:
# System version: 3.7.13 (default, Mar 29 2022, 02:18:16)
# [GCC 7.5.0]
# PyTorch version: 1.11.0+cu102
# Cornac version: 1.14.2

# %%
data_size = '100k'
TOP_k = 10
latent_dim = 50
encoder_dims = [100]
act_func = 'tanh'
likelihood = 'pois'
num_epochs = 500
batch_size = 128
learning_rate = 0.001

# %% [markdown]
# ## 1. Theory
# ## 2. Cornac implementation of BiVAE
# - Cornac에 있는 BiVAE 모델의 자세한 문서는 [여기](https://cornac.readthedocs.io/en/latest/models.html#module-cornac.models.bivaecf.recom_bivaecf)
# - BiVAE 실행에 대한 소스코드는 [여기](https://github.com/PreferredAI/cornac/tree/master/cornac/models/bivaecf)
# - BiVAE와 관련된 모든 실험은 [여기](https://github.com/PreferredAI/bi-vae)를 참고
#
# ## 3. Experiments on Movielens

# %%
# Load and split data
data = pd.read_csv('Movielens_100k.csv')
data = data[['UserId', 'MovieId', 'Rating']]
data.head()
# Out:
#    UserId  MovieId  Rating
# 0     196      242     3.0
# 1     186      302     3.0
# 2      22      377     1.0
# 3     244       51     2.0
# 4     166      346     1.0

# %%
train, test = python_random_split(data, 0.75)

# %% [markdown]
# ### Cornac Dataset
# Cornac의 모델들로 작업하려면 Dataset 클래스를 만들어야 한다. Cornac의 Dataset 클래스는 모델이 직접 상호작용하는 메인 오브젝트이다. 데이터 변형에 더해, 데이터를 순회하는 유용한 iterator들을 제공하고, negative 샘플링 기술들을 지원한다.

# %%
train_set = cornac.data.Dataset.from_uir(train.itertuples(index=False), seed=SEED)
print('Number of users: {}'.format(train_set.num_users))
print('Number of items: {}'.format(train_set.num_items))
# Out:
# Number of users: 943
# Number of items: 1642

# %%
for i in train.itertuples(index=False):
    print(i)
# Out:
# Pandas(UserId=811, MovieId=901, Rating=4.0)
# Pandas(UserId=804, MovieId=755, Rating=3.0)
# Pandas(UserId=52, MovieId=287, Rating=5.0)
# Pandas(UserId=735, MovieId=181, Rating=4.0)
# Pandas(UserId=897, MovieId=96, Rating=5.0)
# Pandas(UserId=934, MovieId=83, Rating=4.0)
# Pandas(UserId=933, MovieId=1, Rating=3.0)
# Pandas(UserId=57, MovieId=225, Rating=3.0)
# Pandas(UserId=389, MovieId=199, Rating=5.0)
# Pandas(UserId=759, MovieId=181, Rating=5.0)
# Pandas(UserId=805, MovieId=24, Rating=4.0)
# Pandas(UserId=693, MovieId=632, Rating=5.0)
# Pandas(UserId=683, MovieId=321, Rating=5.0)
# Pandas(UserId=856, MovieId=272, Rating=5.0)
# Pandas(UserId=445, MovieId=544, Rating=2.0)
# Pandas(UserId=7, MovieId=472, Rating=2.0)
# Pandas(UserId=409, MovieId=266, Rating=1.0)
# Pandas(UserId=103, MovieId=127, Rating=4.0)
# Pandas(UserId=394, MovieId=651, Rating=4.0)
# Pandas(UserId=313, MovieId=969, Rating=4.0)
# Pandas(UserId=655, MovieId=896, Rating=4.0)
# Pandas(UserId=655, MovieId=1008, Rating=3.0)
# Pandas(UserId=280, MovieId=449, Rating=3.0)
# Pandas(UserId=426, MovieId=418, Rating=3.0)
# Pandas(UserId=496, MovieId=174, Rating=4.0)
# Pandas(UserId=807, MovieId=1444, Rating=3.0)
# Pandas(UserId=303, MovieId=443, Rating=4.0)
# Pandas(UserId=64, MovieId=1, Rating=4.0)
# Pandas(UserId=933, MovieId=42, Rating=1.0)
# Pandas(UserId=595, MovieId=994, Rating=4.0)
# Pandas(UserId=276, MovieId=407, Rating=2.0)
# Pandas(UserId=189, MovieId=661, Rating=4.0)
# Pandas(UserId=174, MovieId=1032, Rating=3.0)
# Pandas(UserId=919, MovieId=283, Rating=4.0)
# Pandas(UserId=119, MovieId=332, Rating=4.0)
# Pandas(UserId=641, MovieId=134, Rating=5.0)
# Pandas(UserId=669, MovieId=355, Rating=2.0)
# Pandas(UserId=566, MovieId=71, Rating=2.0)
# Pandas(UserId=385, MovieId=145, Rating=1.0)
# Pandas(UserId=393, MovieId=731, Rating=3.0)
# Pandas(UserId=642, MovieId=405, Rating=3.0)
# Pandas(UserId=669, MovieId=300, Rating=4.0)
# Pandas(UserId=161, MovieId=194, Rating=1.0)
# Pandas(UserId=201, MovieId=1, Rating=3.0)
# Pandas(UserId=693, MovieId=121, Rating=2.0)
# Pandas(UserId=858, MovieId=333, Rating=4.0)
# Pandas(UserId=416, MovieId=845, Rating=4.0)
# Pandas(UserId=715, MovieId=73, Rating=4.0)
# Pandas(UserId=592, MovieId=61, Rating=4.0)
# Pandas(UserId=276, MovieId=597, Rating=3.0)
# Pandas(UserId=339, MovieId=415, Rating=3.0)
# Pandas(UserId=345, MovieId=131, Rating=4.0)
# Pandas(UserId=416, MovieId=676, Rating=5.0)
# Pandas(UserId=933, MovieId=636, Rating=2.0)
# Pandas(UserId=774, MovieId=183, Rating=4.0)
# Pandas(UserId=49, MovieId=173, Rating=3.0)
# Pandas(UserId=536, MovieId=190, Rating=5.0)
# Pandas(UserId=707, MovieId=52, Rating=3.0)
# Pandas(UserId=305, MovieId=428, Rating=3.0)
# Pandas(UserId=378, MovieId=736, Rating=4.0)
# Pandas(UserId=267, MovieId=204, Rating=4.0)
# Pandas(UserId=864, MovieId=121, Rating=4.0)
# Pandas(UserId=666, MovieId=1011, Rating=4.0)
# Pandas(UserId=234, MovieId=73, Rating=2.0)
# Pandas(UserId=585, MovieId=730, Rating=3.0)
# Pandas(UserId=553, MovieId=218, Rating=4.0)
# Pandas(UserId=53, MovieId=24, Rating=3.0)
# Pandas(UserId=314, MovieId=155, Rating=5.0)
# Pandas(UserId=374, MovieId=476, Rating=2.0)
# Pandas(UserId=91, MovieId=418, Rating=2.0)
# Pandas(UserId=682, MovieId=378, Rating=3.0)
# Pandas(UserId=567, MovieId=705, Rating=5.0)
# Pandas(UserId=100, MovieId=898, Rating=4.0)
# Pandas(UserId=30, MovieId=50, Rating=3.0)
# Pandas(UserId=234, MovieId=70, Rating=3.0)
# Pandas(UserId=332, MovieId=410, Rating=4.0)
# Pandas(UserId=830, MovieId=203, Rating=4.0)
# Pandas(UserId=349, MovieId=619, Rating=4.0)
# Pandas(UserId=864, MovieId=178, Rating=4.0)
# Pandas(UserId=632, MovieId=133, Rating=4.0)
# Pandas(UserId=102, MovieId=665, Rating=1.0)
# Pandas(UserId=643, MovieId=47, Rating=4.0)
# Pandas(UserId=815, MovieId=521, Rating=4.0)
# Pandas(UserId=66, MovieId=127, Rating=4.0)
# Pandas(UserId=417, MovieId=1182, Rating=3.0)
# Pandas(UserId=799, MovieId=427, Rating=5.0)
# Pandas(UserId=856, MovieId=326, Rating=2.0)
# Pandas(UserId=309, MovieId=938, Rating=4.0)
# Pandas(UserId=716, MovieId=493, Rating=5.0)
# Pandas(UserId=297, MovieId=275, Rating=5.0)
# Pandas(UserId=189, MovieId=24, Rating=4.0)
# Pandas(UserId=560, MovieId=134, Rating=5.0)
# Pandas(UserId=472, MovieId=685, Rating=3.0)
# Pandas(UserId=391, MovieId=71, Rating=3.0)
# Pandas(UserId=437, MovieId=512, Rating=4.0)
# Pandas(UserId=92, MovieId=846, Rating=3.0)
# Pandas(UserId=844, MovieId=89, Rating=3.0)
# Pandas(UserId=545, MovieId=28, Rating=4.0)
# Pandas(UserId=24, MovieId=518, Rating=4.0)
# Pandas(UserId=49, MovieId=47, Rating=5.0)
# Pandas(UserId=825, MovieId=98, Rating=5.0)
# Pandas(UserId=372, MovieId=219, Rating=5.0)
# Pandas(UserId=336, MovieId=742, Rating=3.0)
# Pandas(UserId=308, MovieId=209, Rating=4.0)
# Pandas(UserId=897, MovieId=173, Rating=3.0)
# Pandas(UserId=312, MovieId=603, Rating=5.0)
# Pandas(UserId=524, MovieId=39, Rating=5.0)
# Pandas(UserId=546, MovieId=288, Rating=4.0)
# Pandas(UserId=409, MovieId=479, Rating=5.0)
# Pandas(UserId=330, MovieId=596, Rating=5.0)
# Pandas(UserId=405, MovieId=1438, Rating=1.0)
# Pandas(UserId=213, MovieId=172, Rating=5.0)
# Pandas(UserId=94, MovieId=357, Rating=5.0)
# Pandas(UserId=442, MovieId=385, Rating=3.0)
# Pandas(UserId=299, MovieId=517, Rating=4.0)
# Pandas(UserId=716, MovieId=230, Rating=3.0)
# Pandas(UserId=543, MovieId=944, Rating=3.0)
# Pandas(UserId=345, MovieId=248, Rating=5.0)
# Pandas(UserId=716, MovieId=186, Rating=3.0)
# Pandas(UserId=342, MovieId=410, Rating=3.0)
# Pandas(UserId=815, MovieId=631, Rating=4.0)
# Pandas(UserId=825, MovieId=931, Rating=3.0)
# Pandas(UserId=562, MovieId=286, Rating=4.0)
# Pandas(UserId=719, MovieId=240, Rating=1.0)
# Pandas(UserId=788, MovieId=230, Rating=3.0)
# Pandas(UserId=409, MovieId=59, Rating=5.0)
# Pandas(UserId=112, MovieId=306, Rating=5.0)
# Pandas(UserId=387, MovieId=514, Rating=3.0)
# Pandas(UserId=266, MovieId=100, Rating=5.0)
# Pandas(UserId=300, MovieId=243, Rating=4.0)
# Pandas(UserId=324, MovieId=690, Rating=4.0)
# Pandas(UserId=234, MovieId=178, Rating=5.0)
# Pandas(UserId=299, MovieId=270, Rating=4.0)
# Pandas(UserId=154, MovieId=288, Rating=3.0)
# Pandas(UserId=834, MovieId=287, Rating=2.0)
# Pandas(UserId=586, MovieId=177, Rating=3.0)
# Pandas(UserId=922, MovieId=143, Rating=4.0)
# Pandas(UserId=632, MovieId=419, Rating=4.0)
# Pandas(UserId=11, MovieId=747, Rating=3.0)
# Pandas(UserId=518, MovieId=595, Rating=3.0)
# Pandas(UserId=299, MovieId=56, Rating=4.0)
# Pandas(UserId=939, MovieId=237, Rating=5.0)
# Pandas(UserId=454, MovieId=988, Rating=2.0)
# Pandas(UserId=247, MovieId=269, Rating=4.0)
# Pandas(UserId=644, MovieId=181, Rating=4.0)
# Pandas(UserId=796, MovieId=1407, Rating=3.0)
# Pandas(UserId=715, MovieId=232, Rating=4.0)
# Pandas(UserId=637, MovieId=235, Rating=1.0)
# Pandas(UserId=642, MovieId=959, Rating=5.0)
# Pandas(UserId=299, MovieId=17, Rating=1.0)
# Pandas(UserId=303, MovieId=631, Rating=4.0)
# Pandas(UserId=490, MovieId=1067, Rating=2.0)
# Pandas(UserId=580, MovieId=323, Rating=2.0)
# Pandas(UserId=85, MovieId=496, Rating=4.0)
# Pandas(UserId=504, MovieId=1508, Rating=3.0)
# Pandas(UserId=392, MovieId=8, Rating=5.0)
# Pandas(UserId=182, MovieId=479, Rating=5.0)
# Pandas(UserId=116, MovieId=298, Rating=3.0)
# Pandas(UserId=388, MovieId=326, Rating=5.0)
# Pandas(UserId=253, MovieId=234, Rating=4.0)
# Pandas(UserId=227, MovieId=121, Rating=2.0)
# Pandas(UserId=588, MovieId=365, Rating=5.0)
# Pandas(UserId=815, MovieId=393, Rating=4.0)
# Pandas(UserId=545, MovieId=135, Rating=4.0)
# Pandas(UserId=230, MovieId=499, Rating=4.0)
# Pandas(UserId=387, MovieId=735, Rating=2.0)
# Pandas(UserId=116, MovieId=1254, Rating=2.0)
# Pandas(UserId=194, MovieId=83, Rating=3.0)
# Pandas(UserId=336, MovieId=1496, Rating=1.0)
# Pandas(UserId=401, MovieId=630, Rating=4.0)
# Pandas(UserId=119, MovieId=22, Rating=4.0)
# Pandas(UserId=846, MovieId=385, Rating=5.0)
# Pandas(UserId=595, MovieId=744, Rating=3.0)
# Pandas(UserId=541, MovieId=588, Rating=4.0)
# Pandas(UserId=339, MovieId=185, Rating=4.0)
# Pandas(UserId=270, MovieId=279, Rating=5.0)
# Pandas(UserId=182, MovieId=864, Rating=4.0)
# Pandas(UserId=582, MovieId=1033, Rating=2.0)
# Pandas(UserId=309, MovieId=690, Rating=3.0)
# Pandas(UserId=825, MovieId=678, Rating=4.0)
# Pandas(UserId=537, MovieId=628, Rating=2.0)
# Pandas(UserId=537, MovieId=286, Rating=3.0)
# Pandas(UserId=868, MovieId=50, Rating=5.0)
# Pandas(UserId=764, MovieId=98, Rating=5.0)
# Pandas(UserId=89, MovieId=15, Rating=5.0)
# Pandas(UserId=479, MovieId=688, Rating=1.0)
# Pandas(UserId=747, MovieId=811, Rating=3.0)
# Pandas(UserId=210, MovieId=751, Rating=4.0)
# Pandas(UserId=827, MovieId=258, Rating=3.0)
# Pandas(UserId=102, MovieId=1, Rating=3.0)
# Pandas(UserId=151, MovieId=25, Rating=4.0)
# Pandas(UserId=889, MovieId=65, Rating=4.0)
# Pandas(UserId=844, MovieId=12, Rating=5.0)
# Pandas(UserId=559, MovieId=528, Rating=4.0)
# Pandas(UserId=7, MovieId=515, Rating=3.0)
# Pandas(UserId=18, MovieId=165, Rating=4.0)
# Pandas(UserId=181, MovieId=409, Rating=2.0)
# Pandas(UserId=922, MovieId=252, Rating=2.0)
# Pandas(UserId=59, MovieId=180, Rating=4.0)
# Pandas(UserId=828, MovieId=694, Rating=2.0)
# Pandas(UserId=53, MovieId=546, Rating=4.0)
# Pandas(UserId=342, MovieId=663, Rating=4.0)
# Pandas(UserId=843, MovieId=200, Rating=3.0)
# Pandas(UserId=109, MovieId=393, Rating=4.0)
# Pandas(UserId=222, MovieId=258, Rating=5.0)
# Pandas(UserId=221, MovieId=69, Rating=4.0)
# Pandas(UserId=244, MovieId=58, Rating=3.0)
# Pandas(UserId=405, MovieId=206, Rating=1.0)
# Pandas(UserId=334, MovieId=1504, Rating=3.0)
# Pandas(UserId=587, MovieId=1625, Rating=4.0)
# Pandas(UserId=198, MovieId=431, Rating=3.0)
# Pandas(UserId=634, MovieId=690, Rating=3.0)
# Pandas(UserId=632, MovieId=150, Rating=2.0)
# Pandas(UserId=458, MovieId=603, Rating=4.0)
# Pandas(UserId=766, MovieId=174, Rating=3.0)
# Pandas(UserId=503, MovieId=116, Rating=5.0)
# Pandas(UserId=609, MovieId=948, Rating=1.0)
# Pandas(UserId=514, MovieId=1039, Rating=5.0)
# Pandas(UserId=552, MovieId=240, Rating=2.0)
# Pandas(UserId=437, MovieId=674, Rating=3.0)
# Pandas(UserId=429, MovieId=70, Rating=4.0)
# Pandas(UserId=484, MovieId=829, Rating=2.0)
# Pandas(UserId=911, MovieId=655, Rating=5.0)
# Pandas(UserId=254, MovieId=323, Rating=3.0)
# Pandas(UserId=871, MovieId=121, Rating=4.0)
# Pandas(UserId=703, MovieId=275, Rating=4.0)
# Pandas(UserId=934, MovieId=69, Rating=5.0)
# Pandas(UserId=236, MovieId=696, Rating=2.0)
# Pandas(UserId=286, MovieId=778, Rating=5.0)
# Pandas(UserId=125, MovieId=493, Rating=4.0)
# Pandas(UserId=840, MovieId=511, Rating=4.0)
# Pandas(UserId=10, MovieId=511, Rating=4.0)
# Pandas(UserId=854, MovieId=293, Rating=5.0)
# Pandas(UserId=393, MovieId=739, Rating=3.0)
# Pandas(UserId=308, MovieId=699, Rating=4.0)
# Pandas(UserId=387, MovieId=82, Rating=4.0)
# Pandas(UserId=442, MovieId=928, Rating=3.0)
# Pandas(UserId=222, MovieId=1139, Rating=3.0)
# Pandas(UserId=716, MovieId=521, Rating=3.0)
# Pandas(UserId=650, MovieId=478, Rating=4.0)
# Pandas(UserId=343, MovieId=288, Rating=2.0)
# Pandas(UserId=389, MovieId=132, Rating=5.0)
# Pandas(UserId=829, MovieId=125, Rating=3.0)
# Pandas(UserId=311, MovieId=99, Rating=5.0)
# Pandas(UserId=601, MovieId=225, Rating=1.0)
# Pandas(UserId=648, MovieId=423, Rating=4.0)
# Pandas(UserId=343, MovieId=67, Rating=3.0)
# Pandas(UserId=379, MovieId=54, Rating=2.0)
# Pandas(UserId=94, MovieId=588, Rating=4.0)
# Pandas(UserId=749, MovieId=480, Rating=5.0)
# Pandas(UserId=5, MovieId=172, Rating=5.0)
# Pandas(UserId=104, MovieId=325, Rating=1.0)
# Pandas(UserId=723, MovieId=258, Rating=4.0)
# Pandas(UserId=195, MovieId=1084, Rating=4.0)
# Pandas(UserId=450, MovieId=400, Rating=3.0)
# Pandas(UserId=545, MovieId=1188, Rating=3.0)
# Pandas(UserId=288, MovieId=1039, Rating=2.0)
# Pandas(UserId=932, MovieId=45, Rating=5.0)
# Pandas(UserId=741, MovieId=69, Rating=4.0)
# Pandas(UserId=21, MovieId=298, Rating=5.0)
# Pandas(UserId=541, MovieId=139, Rating=3.0)
# Pandas(UserId=942, MovieId=71, Rating=5.0)
# Pandas(UserId=931, MovieId=303, Rating=4.0)
# Pandas(UserId=130, MovieId=300, Rating=5.0)
# Pandas(UserId=654, MovieId=22, Rating=5.0)
# Pandas(UserId=239, MovieId=647, Rating=5.0)
# Pandas(UserId=919, MovieId=168, Rating=1.0)
# Pandas(UserId=450, MovieId=60, Rating=3.0)
# Pandas(UserId=68, MovieId=178, Rating=5.0)
# Pandas(UserId=57, MovieId=64, Rating=5.0)
# Pandas(UserId=18, MovieId=629, Rating=3.0)
# Pandas(UserId=17, MovieId=294, Rating=4.0)
# Pandas(UserId=277, MovieId=274, Rating=4.0)
# Pandas(UserId=827, MovieId=326, Rating=3.0)
# Pandas(UserId=766, MovieId=192, Rating=4.0)
# Pandas(UserId=796, MovieId=855, Rating=3.0)
# Pandas(UserId=805, MovieId=665, Rating=4.0)
# Pandas(UserId=389, MovieId=642, Rating=4.0)
# Pandas(UserId=840, MovieId=64, Rating=4.0)
# Pandas(UserId=454, MovieId=181, Rating=3.0)
# Pandas(UserId=166, MovieId=300, Rating=5.0)
# Pandas(UserId=514, MovieId=435, Rating=3.0)
# Pandas(UserId=743, MovieId=408, Rating=4.0)
# Pandas(UserId=709, MovieId=11, Rating=5.0)
# Pandas(UserId=344, MovieId=479, Rating=4.0)
# Pandas(UserId=484, MovieId=237, Rating=3.0)
# Pandas(UserId=541, MovieId=38, Rating=3.0)
# Pandas(UserId=401, MovieId=357, Rating=4.0)
# Pandas(UserId=905, MovieId=322, Rating=3.0)
# Pandas(UserId=860, MovieId=216, Rating=4.0)
# Pandas(UserId=664, MovieId=479, Rating=5.0)
# Pandas(UserId=189, MovieId=281, Rating=2.0)
# Pandas(UserId=788, MovieId=44, Rating=4.0)
# Pandas(UserId=868, MovieId=128, Rating=5.0)
# Pandas(UserId=942, MovieId=303, Rating=4.0)
# Pandas(UserId=214, MovieId=1129, Rating=4.0)
# Pandas(UserId=293, MovieId=175, Rating=2.0)
# Pandas(UserId=697, MovieId=336, Rating=3.0)
# Pandas(UserId=521, MovieId=50, Rating=4.0)
# Pandas(UserId=639, MovieId=213, Rating=5.0)
# Pandas(UserId=899, MovieId=518, Rating=4.0)
# Pandas(UserId=863, MovieId=538, Rating=2.0)
# Pandas(UserId=70, MovieId=1145, Rating=3.0)
# Pandas(UserId=435, MovieId=447, Rating=3.0)
# Pandas(UserId=577, MovieId=240, Rating=3.0)
# Pandas(UserId=303, MovieId=1426, Rating=2.0)
# Pandas(UserId=540, MovieId=50, Rating=5.0)
# Pandas(UserId=577, MovieId=763, Rating=3.0)
# Pandas(UserId=496, MovieId=1444, Rating=1.0)
# Pandas(UserId=508, MovieId=528, Rating=5.0)
# Pandas(UserId=838, MovieId=249, Rating=4.0)
# Pandas(UserId=393, MovieId=410, Rating=4.0)
# Pandas(UserId=141, MovieId=1059, Rating=1.0)
# Pandas(UserId=72, MovieId=89, Rating=3.0)
# Pandas(UserId=391, MovieId=64, Rating=5.0)
# Pandas(UserId=881, MovieId=140, Rating=2.0)
# Pandas(UserId=201, MovieId=93, Rating=5.0)
# Pandas(UserId=7, MovieId=77, Rating=5.0)
# Pandas(UserId=7, MovieId=605, Rating=4.0)
# Pandas(UserId=704, MovieId=480, Rating=5.0)
# Pandas(UserId=293, MovieId=779, Rating=1.0)
# Pandas(UserId=28, MovieId=567, Rating=4.0)
# Pandas(UserId=529, MovieId=271, Rating=4.0)
# Pandas(UserId=311, MovieId=1041, Rating=3.0)
# Pandas(UserId=16, MovieId=98, Rating=5.0)
# Pandas(UserId=387, MovieId=188, Rating=5.0)
# Pandas(UserId=19, MovieId=4, Rating=4.0)
# Pandas(UserId=744, MovieId=23, Rating=4.0)
# Pandas(UserId=624, MovieId=833, Rating=4.0)
# Pandas(UserId=875, MovieId=268, Rating=4.0)
# Pandas(UserId=796, MovieId=443, Rating=2.0)
# Pandas(UserId=143, MovieId=315, Rating=4.0)
# Pandas(UserId=853, MovieId=358, Rating=1.0)
# Pandas(UserId=70, MovieId=739, Rating=2.0)
# Pandas(UserId=892, MovieId=625, Rating=3.0)
# Pandas(UserId=489, MovieId=876, Rating=2.0)
# Pandas(UserId=689, MovieId=222, Rating=5.0)
# Pandas(UserId=201, MovieId=803, Rating=2.0)
# Pandas(UserId=379, MovieId=251, Rating=5.0)
# Pandas(UserId=94, MovieId=218, Rating=3.0)
# Pandas(UserId=870, MovieId=1412, Rating=2.0)
# Pandas(UserId=561, MovieId=1110, Rating=2.0)
# Pandas(UserId=268, MovieId=209, Rating=4.0)
# Pandas(UserId=176, MovieId=305, Rating=5.0)
# Pandas(UserId=96, MovieId=185, Rating=5.0)
# Pandas(UserId=13, MovieId=663, Rating=5.0)
# Pandas(UserId=405, MovieId=714, Rating=1.0)
# Pandas(UserId=727, MovieId=491, Rating=4.0)
# Pandas(UserId=924, MovieId=129, Rating=4.0)
# Pandas(UserId=286, MovieId=432, Rating=3.0)
# Pandas(UserId=504, MovieId=28, Rating=4.0)
# Pandas(UserId=286, MovieId=269, Rating=5.0)
# Pandas(UserId=471, MovieId=102, Rating=5.0)
# Pandas(UserId=268, MovieId=159, Rating=2.0)
# Pandas(UserId=528, MovieId=479, Rating=4.0)
# Pandas(UserId=533, MovieId=265, Rating=3.0)
# Pandas(UserId=792, MovieId=1164, Rating=3.0)
# Pandas(UserId=293, MovieId=174, Rating=5.0)
# Pandas(UserId=261, MovieId=1237, Rating=3.0)
# Pandas(UserId=623, MovieId=435, Rating=5.0)
# Pandas(UserId=428, MovieId=340, Rating=4.0)
# Pandas(UserId=421, MovieId=174, Rating=5.0)
# Pandas(UserId=416, MovieId=918, Rating=4.0)
# Pandas(UserId=715, MovieId=248, Rating=4.0)
# Pandas(UserId=704, MovieId=154, Rating=3.0)
# Pandas(UserId=354, MovieId=516, Rating=5.0)
# Pandas(UserId=781, MovieId=69, Rating=3.0)
# Pandas(UserId=247, MovieId=50, Rating=5.0)
# Pandas(UserId=497, MovieId=252, Rating=3.0)
# Pandas(UserId=557, MovieId=325, Rating=3.0)
# Pandas(UserId=825, MovieId=472, Rating=5.0)
# Pandas(UserId=254, MovieId=269, Rating=2.0)
# Pandas(UserId=334, MovieId=1404, Rating=4.0)
# Pandas(UserId=882, MovieId=202, Rating=4.0)
# Pandas(UserId=557, MovieId=292, Rating=4.0)
# Pandas(UserId=617, MovieId=424, Rating=1.0)
# Pandas(UserId=389, MovieId=736, Rating=5.0)
# Pandas(UserId=271, MovieId=410, Rating=2.0)
# Pandas(UserId=294, MovieId=122, Rating=3.0)
# Pandas(UserId=181, MovieId=986, Rating=2.0)
# Pandas(UserId=577, MovieId=202, Rating=4.0)
# Pandas(UserId=864, MovieId=419, Rating=4.0)
# Pandas(UserId=913, MovieId=508, Rating=3.0)
# Pandas(UserId=780, MovieId=50, Rating=5.0)
# Pandas(UserId=721, MovieId=1392, Rating=3.0)
# Pandas(UserId=545, MovieId=384, Rating=3.0)
# Pandas(UserId=308, MovieId=607, Rating=3.0)
# Pandas(UserId=885, MovieId=239, Rating=3.0)
# Pandas(UserId=339, MovieId=522, Rating=5.0)
# Pandas(UserId=751, MovieId=237, Rating=2.0)
# Pandas(UserId=97, MovieId=194, Rating=3.0)
# Pandas(UserId=610, MovieId=735, Rating=3.0)
# Pandas(UserId=775, MovieId=313, Rating=4.0)
# Pandas(UserId=118, MovieId=427, Rating=5.0)
# Pandas(UserId=490, MovieId=7, Rating=3.0)
# Pandas(UserId=342, MovieId=192, Rating=4.0)
# Pandas(UserId=940, MovieId=1401, Rating=1.0)
# Pandas(UserId=50, MovieId=276, Rating=2.0)
# Pandas(UserId=213, MovieId=756, Rating=2.0)
# Pandas(UserId=200, MovieId=401, Rating=2.0)
# Pandas(UserId=178, MovieId=174, Rating=5.0)
# Pandas(UserId=788, MovieId=693, Rating=2.0)
# Pandas(UserId=686, MovieId=194, Rating=5.0)
# Pandas(UserId=634, MovieId=742, Rating=4.0)
# Pandas(UserId=693, MovieId=403, Rating=2.0)
# Pandas(UserId=79, MovieId=1161, Rating=2.0)
# Pandas(UserId=389, MovieId=1074, Rating=2.0)
# Pandas(UserId=499, MovieId=902, Rating=5.0)
# Pandas(UserId=672, MovieId=476, Rating=5.0)
# Pandas(UserId=699, MovieId=985, Rating=3.0)
# Pandas(UserId=661, MovieId=210, Rating=5.0)
# Pandas(UserId=742, MovieId=15, Rating=4.0)
# Pandas(UserId=906, MovieId=307, Rating=3.0)
# Pandas(UserId=21, MovieId=706, Rating=2.0)
# Pandas(UserId=528, MovieId=310, Rating=3.0)
# Pandas(UserId=332, MovieId=50, Rating=5.0)
# Pandas(UserId=416, MovieId=755, Rating=4.0)
# Pandas(UserId=690, MovieId=1042, Rating=4.0)
# Pandas(UserId=346, MovieId=219, Rating=2.0)
# Pandas(UserId=183, MovieId=203, Rating=3.0)
# Pandas(UserId=864, MovieId=286, Rating=5.0)
# Pandas(UserId=620, MovieId=682, Rating=2.0)
# Pandas(UserId=807, MovieId=1091, Rating=3.0)
# Pandas(UserId=457, MovieId=214, Rating=5.0)
# Pandas(UserId=805, MovieId=952, Rating=5.0)
# Pandas(UserId=731, MovieId=170, Rating=5.0)
# Pandas(UserId=666, MovieId=50, Rating=3.0)
# Pandas(UserId=439, MovieId=257, Rating=4.0)
# Pandas(UserId=524, MovieId=238, Rating=4.0)
# Pandas(UserId=523, MovieId=722, Rating=3.0)
# Pandas(UserId=7, MovieId=183, Rating=4.0)
# Pandas(UserId=711, MovieId=50, Rating=4.0)
# Pandas(UserId=389, MovieId=1203, Rating=5.0)
# Pandas(UserId=901, MovieId=250, Rating=3.0)
# Pandas(UserId=399, MovieId=1246, Rating=1.0)
# Pandas(UserId=878, MovieId=20, Rating=2.0)
# Pandas(UserId=693, MovieId=697, Rating=4.0)
# Pandas(UserId=669, MovieId=252, Rating=2.0)
# Pandas(UserId=444, MovieId=269, Rating=4.0)
# Pandas(UserId=102, MovieId=2, Rating=2.0)
# Pandas(UserId=497, MovieId=288, Rating=2.0)
# Pandas(UserId=370, MovieId=302, Rating=5.0)
# Pandas(UserId=452, MovieId=183, Rating=4.0)
# Pandas(UserId=399, MovieId=561, Rating=2.0)
# Pandas(UserId=429, MovieId=772, Rating=3.0)
# Pandas(UserId=212, MovieId=511, Rating=4.0)
# Pandas(UserId=673, MovieId=268, Rating=1.0)
# Pandas(UserId=314, MovieId=685, Rating=4.0)
# Pandas(UserId=370, MovieId=210, Rating=3.0)
# Pandas(UserId=642, MovieId=417, Rating=3.0)
# Pandas(UserId=291, MovieId=172, Rating=5.0)
# Pandas(UserId=218, MovieId=204, Rating=3.0)
# Pandas(UserId=647, MovieId=705, Rating=4.0)
# Pandas(UserId=804, MovieId=1139, Rating=3.0)
# Pandas(UserId=326, MovieId=180, Rating=1.0)
# Pandas(UserId=59, MovieId=65, Rating=4.0)
# Pandas(UserId=711, MovieId=1014, Rating=4.0)
# Pandas(UserId=271, MovieId=126, Rating=3.0)
# Pandas(UserId=222, MovieId=247, Rating=1.0)
# Pandas(UserId=541, MovieId=465, Rating=4.0)
# Pandas(UserId=87, MovieId=254, Rating=4.0)
# Pandas(UserId=70, MovieId=28, Rating=4.0)
# Pandas(UserId=878, MovieId=64, Rating=5.0)
# Pandas(UserId=291, MovieId=1220, Rating=5.0)
# Pandas(UserId=233, MovieId=958, Rating=5.0)
# Pandas(UserId=325, MovieId=127, Rating=5.0)
# Pandas(UserId=537, MovieId=431, Rating=4.0)
# Pandas(UserId=350, MovieId=489, Rating=4.0)
# Pandas(UserId=59, MovieId=52, Rating=4.0)
# Pandas(UserId=130, MovieId=1276, Rating=4.0)
# Pandas(UserId=774, MovieId=97, Rating=2.0)
# Pandas(UserId=525, MovieId=676, Rating=2.0)
# Pandas(UserId=90, MovieId=287, Rating=4.0)
# Pandas(UserId=682, MovieId=386, Rating=2.0)
# Pandas(UserId=711, MovieId=741, Rating=4.0)
# Pandas(UserId=90, MovieId=676, Rating=2.0)
# Pandas(UserId=125, MovieId=195, Rating=5.0)
# Pandas(UserId=340, MovieId=662, Rating=2.0)
# Pandas(UserId=629, MovieId=127, Rating=5.0)
# Pandas(UserId=553, MovieId=86, Rating=3.0)
# Pandas(UserId=533, MovieId=1177, Rating=1.0)
# Pandas(UserId=328, MovieId=300, Rating=5.0)
# Pandas(UserId=71, MovieId=462, Rating=5.0)
# Pandas(UserId=344, MovieId=709, Rating=5.0)
# Pandas(UserId=758, MovieId=919, Rating=5.0)
# Pandas(UserId=894, MovieId=297, Rating=4.0)
# Pandas(UserId=518, MovieId=547, Rating=3.0)
# Pandas(UserId=63, MovieId=289, Rating=2.0)
# Pandas(UserId=374, MovieId=554, Rating=2.0)
# Pandas(UserId=90, MovieId=661, Rating=5.0)
# Pandas(UserId=504, MovieId=1050, Rating=4.0)
# Pandas(UserId=503, MovieId=100, Rating=5.0)
# Pandas(UserId=316, MovieId=187, Rating=2.0)
# Pandas(UserId=882, MovieId=526, Rating=4.0)
# Pandas(UserId=297, MovieId=752, Rating=4.0)
# Pandas(UserId=760, MovieId=25, Rating=2.0)
# Pandas(UserId=906, MovieId=283, Rating=4.0)
# Pandas(UserId=621, MovieId=28, Rating=4.0)
# Pandas(UserId=804, MovieId=739, Rating=4.0)
# Pandas(UserId=513, MovieId=405, Rating=3.0)
# Pandas(UserId=201, MovieId=221, Rating=3.0)
# Pandas(UserId=561, MovieId=32, Rating=4.0)
# Pandas(UserId=795, MovieId=931, Rating=2.0)
# Pandas(UserId=566, MovieId=213, Rating=5.0)
# Pandas(UserId=682, MovieId=366, Rating=4.0)
# Pandas(UserId=327, MovieId=154, Rating=4.0)
# Pandas(UserId=633, MovieId=176, Rating=3.0)
# Pandas(UserId=277, MovieId=93, Rating=4.0)
# Pandas(UserId=896, MovieId=735, Rating=3.0)
# Pandas(UserId=178, MovieId=328, Rating=3.0)
# Pandas(UserId=864, MovieId=223, Rating=5.0)
# Pandas(UserId=387, MovieId=101, Rating=4.0)
# Pandas(UserId=7, MovieId=510, Rating=5.0)
# Pandas(UserId=432, MovieId=508, Rating=5.0)
# Pandas(UserId=706, MovieId=333, Rating=1.0)
# Pandas(UserId=896, MovieId=672, Rating=2.0)
# Pandas(UserId=941, MovieId=222, Rating=2.0)
# Pandas(UserId=13, MovieId=394, Rating=2.0)
# Pandas(UserId=82, MovieId=946, Rating=2.0)
# Pandas(UserId=711, MovieId=66, Rating=4.0)
# Pandas(UserId=308, MovieId=959, Rating=3.0)
# Pandas(UserId=68, MovieId=1089, Rating=1.0)
# Pandas(UserId=228, MovieId=812, Rating=5.0)
# Pandas(UserId=443, MovieId=678, Rating=2.0)
# Pandas(UserId=313, MovieId=58, Rating=3.0)
# Pandas(UserId=774, MovieId=655, Rating=1.0)
# Pandas(UserId=655, MovieId=923, Rating=3.0)
# Pandas(UserId=291, MovieId=1489, Rating=2.0)
# Pandas(UserId=273, MovieId=321, Rating=4.0)
# Pandas(UserId=870, MovieId=1, Rating=5.0)
# Pandas(UserId=387, MovieId=10, Rating=4.0)
# Pandas(UserId=406, MovieId=8, Rating=4.0)
# Pandas(UserId=498, MovieId=204, Rating=2.0)
# Pandas(UserId=495, MovieId=95, Rating=3.0)
# Pandas(UserId=493, MovieId=209, Rating=5.0)
# Pandas(UserId=630, MovieId=411, Rating=4.0)
# Pandas(UserId=778, MovieId=780, Rating=3.0)
# Pandas(UserId=606, MovieId=83, Rating=5.0)
# Pandas(UserId=250, MovieId=943, Rating=4.0)
# Pandas(UserId=650, MovieId=489, Rating=3.0)
# Pandas(UserId=13, MovieId=769, Rating=3.0)
# Pandas(UserId=517, MovieId=1177, Rating=5.0)
# Pandas(UserId=912, MovieId=602, Rating=5.0)
# Pandas(UserId=199, MovieId=276, Rating=4.0)
# Pandas(UserId=327, MovieId=435, Rating=4.0)
# Pandas(UserId=185, MovieId=23, Rating=4.0)
# Pandas(UserId=391, MovieId=258, Rating=3.0)
# Pandas(UserId=227, MovieId=249, Rating=2.0)
# Pandas(UserId=749, MovieId=444, Rating=2.0)
# Pandas(UserId=791, MovieId=748, Rating=3.0)
# Pandas(UserId=303, MovieId=591, Rating=4.0)
# Pandas(UserId=815, MovieId=143, Rating=5.0)
# Pandas(UserId=18, MovieId=609, Rating=4.0)
# Pandas(UserId=89, MovieId=815, Rating=4.0)
# Pandas(UserId=31, MovieId=340, Rating=3.0)
# Pandas(UserId=880, MovieId=794, Rating=4.0)
# Pandas(UserId=496, MovieId=143, Rating=3.0)
# Pandas(UserId=258, MovieId=877, Rating=3.0)
# Pandas(UserId=721, MovieId=359, Rating=3.0)
# Pandas(UserId=405, MovieId=1032, Rating=1.0)
# Pandas(UserId=923, MovieId=121, Rating=4.0)
# Pandas(UserId=880, MovieId=864, Rating=3.0)
# Pandas(UserId=97, MovieId=132, Rating=5.0)
# Pandas(UserId=224, MovieId=276, Rating=3.0)
# Pandas(UserId=198, MovieId=175, Rating=3.0)
# Pandas(UserId=188, MovieId=210, Rating=4.0)
# Pandas(UserId=391, MovieId=652, Rating=4.0)
# Pandas(UserId=394, MovieId=449, Rating=3.0)
# Pandas(UserId=707, MovieId=880, Rating=2.0)
# Pandas(UserId=650, MovieId=483, Rating=5.0)
# Pandas(UserId=911, MovieId=923, Rating=4.0)
# Pandas(UserId=450, MovieId=215, Rating=5.0)
# Pandas(UserId=393, MovieId=86, Rating=2.0)
# Pandas(UserId=943, MovieId=127, Rating=5.0)
# Pandas(UserId=327, MovieId=1067, Rating=4.0)
# Pandas(UserId=378, MovieId=286, Rating=5.0)
# Pandas(UserId=429, MovieId=249, Rating=4.0)
# Pandas(UserId=874, MovieId=748, Rating=3.0)
# Pandas(UserId=931, MovieId=909, Rating=5.0)
# Pandas(UserId=30, MovieId=259, Rating=4.0)
# Pandas(UserId=566, MovieId=521, Rating=4.0)
# Pandas(UserId=557, MovieId=346, Rating=2.0)
# Pandas(UserId=445, MovieId=871, Rating=2.0)
# Pandas(UserId=416, MovieId=480, Rating=5.0)
# Pandas(UserId=85, MovieId=316, Rating=3.0)
# Pandas(UserId=880, MovieId=1095, Rating=3.0)
# Pandas(UserId=493, MovieId=327, Rating=5.0)
# Pandas(UserId=43, MovieId=269, Rating=5.0)
# Pandas(UserId=213, MovieId=170, Rating=5.0)
# Pandas(UserId=788, MovieId=550, Rating=3.0)
# Pandas(UserId=194, MovieId=451, Rating=2.0)
# Pandas(UserId=144, MovieId=221, Rating=3.0)
# Pandas(UserId=886, MovieId=56, Rating=4.0)
# Pandas(UserId=640, MovieId=1258, Rating=3.0)
# Pandas(UserId=764, MovieId=278, Rating=4.0)
# Pandas(UserId=836, MovieId=260, Rating=2.0)
# Pandas(UserId=181, MovieId=1117, Rating=2.0)
# Pandas(UserId=280, MovieId=1066, Rating=4.0)
# Pandas(UserId=806, MovieId=238, Rating=4.0)
# Pandas(UserId=901, MovieId=172, Rating=5.0)
# Pandas(UserId=932, MovieId=119, Rating=5.0)
# Pandas(UserId=181, MovieId=756, Rating=2.0)
# Pandas(UserId=670, MovieId=144, Rating=4.0)
# Pandas(UserId=327, MovieId=28, Rating=3.0)
# Pandas(UserId=268, MovieId=364, Rating=3.0)
# Pandas(UserId=167, MovieId=530, Rating=5.0)
# Pandas(UserId=713, MovieId=1127, Rating=3.0)
# Pandas(UserId=334, MovieId=608, Rating=4.0)
# Pandas(UserId=197, MovieId=79, Rating=5.0)
# Pandas(UserId=450, MovieId=781, Rating=4.0)
# Pandas(UserId=642, MovieId=225, Rating=4.0)
# Pandas(UserId=119, MovieId=472, Rating=4.0)
# Pandas(UserId=903, MovieId=204, Rating=3.0)
# Pandas(UserId=132, MovieId=285, Rating=4.0)
# Pandas(UserId=60, MovieId=508, Rating=4.0)
# Pandas(UserId=913, MovieId=8, Rating=2.0)
# Pandas(UserId=345, MovieId=137, Rating=4.0)
# Pandas(UserId=249, MovieId=86, Rating=4.0)
# Pandas(UserId=579, MovieId=209, Rating=4.0)
# Pandas(UserId=297, MovieId=258, Rating=5.0)
# Pandas(UserId=650, MovieId=1118, Rating=3.0)
# Pandas(UserId=859, MovieId=294, Rating=3.0)
# Pandas(UserId=63, MovieId=1, Rating=3.0)
# Pandas(UserId=606, MovieId=282, Rating=4.0)
# Pandas(UserId=443, MovieId=343, Rating=5.0)
# Pandas(UserId=724, MovieId=343, Rating=1.0)
# Pandas(UserId=840, MovieId=252, Rating=4.0)
# Pandas(UserId=387, MovieId=169, Rating=5.0)
# Pandas(UserId=94, MovieId=164, Rating=3.0)
# Pandas(UserId=191, MovieId=301, Rating=4.0)
# Pandas(UserId=653, MovieId=356, Rating=1.0)
# Pandas(UserId=805, MovieId=38, Rating=3.0)
# Pandas(UserId=468, MovieId=926, Rating=2.0)
# Pandas(UserId=615, MovieId=387, Rating=3.0)
# Pandas(UserId=311, MovieId=622, Rating=3.0)
# Pandas(UserId=394, MovieId=229, Rating=3.0)
# Pandas(UserId=134, MovieId=302, Rating=2.0)
# Pandas(UserId=936, MovieId=1163, Rating=5.0)
# Pandas(UserId=100, MovieId=315, Rating=5.0)
# Pandas(UserId=488, MovieId=83, Rating=4.0)
# Pandas(UserId=448, MovieId=1176, Rating=2.0)
# Pandas(UserId=81, MovieId=275, Rating=4.0)
# Pandas(UserId=489, MovieId=902, Rating=4.0)
# Pandas(UserId=17, MovieId=100, Rating=4.0)
# Pandas(UserId=262, MovieId=596, Rating=4.0)
# Pandas(UserId=933, MovieId=746, Rating=4.0)
# Pandas(UserId=455, MovieId=50, Rating=5.0)
# Pandas(UserId=708, MovieId=347, Rating=3.0)
# Pandas(UserId=201, MovieId=118, Rating=1.0)
# Pandas(UserId=919, MovieId=919, Rating=2.0)
# Pandas(UserId=651, MovieId=276, Rating=4.0)
# Pandas(UserId=466, MovieId=350, Rating=4.0)
# Pandas(UserId=276, MovieId=46, Rating=3.0)
# Pandas(UserId=437, MovieId=443, Rating=4.0)
# Pandas(UserId=204, MovieId=310, Rating=1.0)
# Pandas(UserId=54, MovieId=237, Rating=4.0)
# Pandas(UserId=49, MovieId=372, Rating=4.0)
# Pandas(UserId=15, MovieId=473, Rating=1.0)
# Pandas(UserId=423, MovieId=10, Rating=4.0)
# Pandas(UserId=104, MovieId=346, Rating=3.0)
# Pandas(UserId=109, MovieId=949, Rating=3.0)
# Pandas(UserId=92, MovieId=568, Rating=3.0)
# Pandas(UserId=738, MovieId=1047, Rating=3.0)
# Pandas(UserId=536, MovieId=1140, Rating=1.0)
# Pandas(UserId=752, MovieId=326, Rating=1.0)
# Pandas(UserId=598, MovieId=269, Rating=3.0)
# Pandas(UserId=642, MovieId=651, Rating=4.0)
# Pandas(UserId=264, MovieId=219, Rating=5.0)
# Pandas(UserId=155, MovieId=324, Rating=2.0)
# Pandas(UserId=279, MovieId=558, Rating=4.0)
# Pandas(UserId=923, MovieId=741, Rating=5.0)
# Pandas(UserId=924, MovieId=277, Rating=3.0)
# Pandas(UserId=568, MovieId=178, Rating=4.0)
# Pandas(UserId=650, MovieId=155, Rating=2.0)
# Pandas(UserId=798, MovieId=79, Rating=4.0)
# Pandas(UserId=323, MovieId=1073, Rating=4.0)
# Pandas(UserId=320, MovieId=121, Rating=5.0)
# Pandas(UserId=868, MovieId=1285, Rating=2.0)
# Pandas(UserId=757, MovieId=172, Rating=4.0)
# Pandas(UserId=334, MovieId=116, Rating=4.0)
# Pandas(UserId=313, MovieId=478, Rating=3.0)
# Pandas(UserId=611, MovieId=340, Rating=5.0)
# Pandas(UserId=827, MovieId=312, Rating=2.0)
# Pandas(UserId=592, MovieId=1315, Rating=2.0)
# Pandas(UserId=498, MovieId=150, Rating=3.0)
# Pandas(UserId=678, MovieId=285, Rating=3.0)
# Pandas(UserId=87, MovieId=926, Rating=4.0)
# Pandas(UserId=782, MovieId=1388, Rating=3.0)
# Pandas(UserId=682, MovieId=420, Rating=3.0)
# Pandas(UserId=21, MovieId=874, Rating=2.0)
# Pandas(UserId=577, MovieId=121, Rating=5.0)
# Pandas(UserId=327, MovieId=300, Rating=2.0)
# Pandas(UserId=892, MovieId=131, Rating=4.0)
# Pandas(UserId=85, MovieId=715, Rating=4.0)
# Pandas(UserId=881, MovieId=64, Rating=5.0)
# Pandas(UserId=307, MovieId=132, Rating=4.0)
# Pandas(UserId=92, MovieId=587, Rating=3.0)
# Pandas(UserId=689, MovieId=298, Rating=4.0)
# Pandas(UserId=484, MovieId=70, Rating=5.0)
# Pandas(UserId=294, MovieId=546, Rating=4.0)
# Pandas(UserId=463, MovieId=690, Rating=4.0)
# Pandas(UserId=642, MovieId=217, Rating=2.0)
# Pandas(UserId=719, MovieId=215, Rating=4.0)
# Pandas(UserId=804, MovieId=671, Rating=3.0)
# Pandas(UserId=296, MovieId=284, Rating=4.0)
# Pandas(UserId=567, MovieId=490, Rating=4.0)
# Pandas(UserId=24, MovieId=318, Rating=5.0)
# Pandas(UserId=395, MovieId=174, Rating=5.0)
# Pandas(UserId=112, MovieId=1106, Rating=4.0)
# Pandas(UserId=224, MovieId=92, Rating=1.0)
# Pandas(UserId=197, MovieId=510, Rating=5.0)
# Pandas(UserId=389, MovieId=604, Rating=4.0)
# Pandas(UserId=445, MovieId=1009, Rating=2.0)
# Pandas(UserId=561, MovieId=762, Rating=3.0)
# Pandas(UserId=151, MovieId=611, Rating=4.0)
# Pandas(UserId=393, MovieId=3, Rating=3.0)
# Pandas(UserId=11, MovieId=722, Rating=3.0)
# Pandas(UserId=82, MovieId=218, Rating=3.0)
# Pandas(UserId=864, MovieId=22, Rating=5.0)
# Pandas(UserId=368, MovieId=218, Rating=2.0)
# Pandas(UserId=713, MovieId=327, Rating=2.0)
# Pandas(UserId=654, MovieId=405, Rating=4.0)
# Pandas(UserId=470, MovieId=222, Rating=3.0)
# Pandas(UserId=844, MovieId=597, Rating=3.0)
# Pandas(UserId=97, MovieId=169, Rating=5.0)
# Pandas(UserId=818, MovieId=690, Rating=3.0)
# Pandas(UserId=389, MovieId=661, Rating=4.0)
# Pandas(UserId=411, MovieId=4, Rating=4.0)
# Pandas(UserId=463, MovieId=845, Rating=3.0)
# Pandas(UserId=449, MovieId=763, Rating=2.0)
# Pandas(UserId=918, MovieId=707, Rating=5.0)
# Pandas(UserId=904, MovieId=181, Rating=3.0)
# Pandas(UserId=837, MovieId=151, Rating=5.0)
# Pandas(UserId=924, MovieId=705, Rating=5.0)
# Pandas(UserId=751, MovieId=143, Rating=5.0)
# Pandas(UserId=622, MovieId=385, Rating=5.0)
# Pandas(UserId=285, MovieId=902, Rating=4.0)
# Pandas(UserId=138, MovieId=12, Rating=5.0)
# Pandas(UserId=622, MovieId=419, Rating=4.0)
# Pandas(UserId=524, MovieId=410, Rating=2.0)
# Pandas(UserId=715, MovieId=159, Rating=3.0)
# Pandas(UserId=276, MovieId=780, Rating=3.0)
# Pandas(UserId=17, MovieId=475, Rating=4.0)
# Pandas(UserId=18, MovieId=23, Rating=4.0)
# Pandas(UserId=69, MovieId=245, Rating=1.0)
# Pandas(UserId=896, MovieId=191, Rating=4.0)
# Pandas(UserId=608, MovieId=848, Rating=4.0)
# Pandas(UserId=87, MovieId=477, Rating=3.0)
# Pandas(UserId=276, MovieId=450, Rating=1.0)
# Pandas(UserId=738, MovieId=385, Rating=5.0)
# Pandas(UserId=843, MovieId=250, Rating=4.0)
# Pandas(UserId=526, MovieId=123, Rating=3.0)
# Pandas(UserId=393, MovieId=553, Rating=3.0)
# Pandas(UserId=640, MovieId=180, Rating=5.0)
# Pandas(UserId=830, MovieId=418, Rating=3.0)
# Pandas(UserId=389, MovieId=965, Rating=5.0)
# Pandas(UserId=498, MovieId=1142, Rating=4.0)
# Pandas(UserId=657, MovieId=1009, Rating=4.0)
# Pandas(UserId=492, MovieId=531, Rating=4.0)
# Pandas(UserId=321, MovieId=83, Rating=4.0)
# Pandas(UserId=503, MovieId=485, Rating=4.0)
# Pandas(UserId=610, MovieId=288, Rating=3.0)
# Pandas(UserId=339, MovieId=195, Rating=3.0)
# Pandas(UserId=860, MovieId=344, Rating=3.0)
# Pandas(UserId=128, MovieId=218, Rating=3.0)
# Pandas(UserId=234, MovieId=1035, Rating=3.0)
# Pandas(UserId=567, MovieId=183, Rating=4.0)
# Pandas(UserId=440, MovieId=582, Rating=3.0)
# Pandas(UserId=462, MovieId=655, Rating=5.0)
# Pandas(UserId=130, MovieId=222, Rating=4.0)
# Pandas(UserId=346, MovieId=203, Rating=4.0)
# Pandas(UserId=407, MovieId=427, Rating=4.0)
# Pandas(UserId=846, MovieId=219, Rating=4.0)
# Pandas(UserId=535, MovieId=1136, Rating=4.0)
# Pandas(UserId=645, MovieId=182, Rating=5.0)
# Pandas(UserId=655, MovieId=794, Rating=1.0)
# Pandas(UserId=592, MovieId=299, Rating=1.0)
# Pandas(UserId=332, MovieId=871, Rating=3.0)
# Pandas(UserId=222, MovieId=1188, Rating=3.0)
# Pandas(UserId=586, MovieId=1047, Rating=3.0)
# Pandas(UserId=313, MovieId=200, Rating=3.0)
# Pandas(UserId=886, MovieId=66, Rating=3.0)
# Pandas(UserId=697, MovieId=254, Rating=2.0)
# Pandas(UserId=455, MovieId=1174, Rating=3.0)
# Pandas(UserId=655, MovieId=553, Rating=2.0)
# Pandas(UserId=479, MovieId=101, Rating=4.0)
# Pandas(UserId=417, MovieId=679, Rating=2.0)
# Pandas(UserId=394, MovieId=117, Rating=5.0)
# Pandas(UserId=57, MovieId=250, Rating=3.0)
# Pandas(UserId=794, MovieId=187, Rating=5.0)
# Pandas(UserId=87, MovieId=120, Rating=2.0)
# Pandas(UserId=85, MovieId=659, Rating=4.0)
# Pandas(UserId=216, MovieId=789, Rating=5.0)
# Pandas(UserId=847, MovieId=404, Rating=3.0)
# Pandas(UserId=634, MovieId=322, Rating=3.0)
# Pandas(UserId=58, MovieId=367, Rating=5.0)
# Pandas(UserId=49, MovieId=514, Rating=4.0)
# Pandas(UserId=529, MovieId=991, Rating=1.0)
# Pandas(UserId=882, MovieId=183, Rating=4.0)
# Pandas(UserId=541, MovieId=543, Rating=4.0)
# Pandas(UserId=215, MovieId=208, Rating=4.0)
# Pandas(UserId=64, MovieId=705, Rating=5.0)
# Pandas(UserId=308, MovieId=385, Rating=4.0)
# Pandas(UserId=102, MovieId=350, Rating=3.0)
# Pandas(UserId=181, MovieId=1323, Rating=1.0)
# Pandas(UserId=537, MovieId=430, Rating=3.0)
# Pandas(UserId=711, MovieId=52, Rating=5.0)
# Pandas(UserId=901, MovieId=117, Rating=4.0)
# Pandas(UserId=201, MovieId=8, Rating=3.0)
# Pandas(UserId=833, MovieId=923, Rating=5.0)
# Pandas(UserId=721, MovieId=306, Rating=3.0)
# Pandas(UserId=645, MovieId=134, Rating=5.0)
# Pandas(UserId=828, MovieId=198, Rating=4.0)
# Pandas(UserId=109, MovieId=127, Rating=2.0)
# Pandas(UserId=474, MovieId=504, Rating=5.0)
# Pandas(UserId=642, MovieId=726, Rating=2.0)
# Pandas(UserId=405, MovieId=1583, Rating=1.0)
# Pandas(UserId=437, MovieId=219, Rating=3.0)
# Pandas(UserId=706, MovieId=682, Rating=2.0)
# Pandas(UserId=58, MovieId=663, Rating=2.0)
# Pandas(UserId=269, MovieId=821, Rating=1.0)
# Pandas(UserId=405, MovieId=461, Rating=3.0)
# Pandas(UserId=457, MovieId=948, Rating=1.0)
# Pandas(UserId=741, MovieId=121, Rating=2.0)
# Pandas(UserId=417, MovieId=450, Rating=2.0)
# Pandas(UserId=69, MovieId=748, Rating=2.0)
# Pandas(UserId=919, MovieId=877, Rating=3.0)
# Pandas(UserId=291, MovieId=218, Rating=4.0)
# Pandas(UserId=286, MovieId=90, Rating=4.0)
# Pandas(UserId=812, MovieId=286, Rating=2.0)
# Pandas(UserId=838, MovieId=705, Rating=5.0)
# Pandas(UserId=642, MovieId=233, Rating=4.0)
# Pandas(UserId=332, MovieId=562, Rating=5.0)
# Pandas(UserId=577, MovieId=58, Rating=4.0)
# Pandas(UserId=892, MovieId=566, Rating=4.0)
# Pandas(UserId=307, MovieId=89, Rating=5.0)
# Pandas(UserId=835, MovieId=616, Rating=4.0)
# Pandas(UserId=426, MovieId=616, Rating=4.0)
# Pandas(UserId=843, MovieId=416, Rating=2.0)
# Pandas(UserId=529, MovieId=326, Rating=4.0)
# Pandas(UserId=796, MovieId=662, Rating=5.0)
# Pandas(UserId=766, MovieId=8, Rating=5.0)
# Pandas(UserId=280, MovieId=419, Rating=3.0)
# Pandas(UserId=851, MovieId=298, Rating=5.0)
# Pandas(UserId=546, MovieId=457, Rating=1.0)
# Pandas(UserId=24, MovieId=64, Rating=5.0)
# Pandas(UserId=447, MovieId=121, Rating=5.0)
# Pandas(UserId=653, MovieId=693, Rating=1.0)
# Pandas(UserId=416, MovieId=191, Rating=5.0)
# Pandas(UserId=276, MovieId=265, Rating=4.0)
# Pandas(UserId=360, MovieId=207, Rating=4.0)
# Pandas(UserId=144, MovieId=19, Rating=4.0)
# Pandas(UserId=864, MovieId=373, Rating=2.0)
# Pandas(UserId=774, MovieId=429, Rating=1.0)
# Pandas(UserId=794, MovieId=19, Rating=4.0)
# Pandas(UserId=405, MovieId=421, Rating=1.0)
# Pandas(UserId=177, MovieId=144, Rating=5.0)
# Pandas(UserId=843, MovieId=561, Rating=4.0)
# Pandas(UserId=795, MovieId=412, Rating=3.0)
# Pandas(UserId=867, MovieId=135, Rating=5.0)
# Pandas(UserId=268, MovieId=145, Rating=1.0)
# Pandas(UserId=69, MovieId=9, Rating=4.0)
# Pandas(UserId=823, MovieId=1118, Rating=3.0)
# Pandas(UserId=23, MovieId=423, Rating=3.0)
# Pandas(UserId=543, MovieId=83, Rating=4.0)
# Pandas(UserId=758, MovieId=175, Rating=4.0)
# Pandas(UserId=69, MovieId=246, Rating=5.0)
# Pandas(UserId=399, MovieId=1135, Rating=2.0)
# Pandas(UserId=181, MovieId=242, Rating=1.0)
# Pandas(UserId=286, MovieId=96, Rating=4.0)
# Pandas(UserId=910, MovieId=357, Rating=4.0)
# Pandas(UserId=600, MovieId=27, Rating=3.0)
# Pandas(UserId=269, MovieId=77, Rating=1.0)
# Pandas(UserId=7, MovieId=542, Rating=4.0)
# Pandas(UserId=198, MovieId=216, Rating=4.0)
# Pandas(UserId=11, MovieId=51, Rating=4.0)
# Pandas(UserId=622, MovieId=866, Rating=2.0)
# Pandas(UserId=533, MovieId=660, Rating=5.0)
# Pandas(UserId=76, MovieId=806, Rating=4.0)
# Pandas(UserId=611, MovieId=307, Rating=4.0)
# Pandas(UserId=838, MovieId=8, Rating=4.0)
# Pandas(UserId=172, MovieId=183, Rating=5.0)
# Pandas(UserId=269, MovieId=157, Rating=3.0)
# Pandas(UserId=90, MovieId=1020, Rating=5.0)
# Pandas(UserId=682, MovieId=678, Rating=1.0)
# Pandas(UserId=634, MovieId=221, Rating=1.0)
# Pandas(UserId=280, MovieId=144, Rating=2.0)
# Pandas(UserId=226, MovieId=713, Rating=5.0)
# Pandas(UserId=299, MovieId=1507, Rating=3.0)
# Pandas(UserId=16, MovieId=770, Rating=3.0)
# Pandas(UserId=128, MovieId=685, Rating=3.0)
# Pandas(UserId=181, MovieId=330, Rating=1.0)
# Pandas(UserId=764, MovieId=281, Rating=3.0)
# Pandas(UserId=916, MovieId=735, Rating=4.0)
# Pandas(UserId=782, MovieId=984, Rating=2.0)
# Pandas(UserId=233, MovieId=498, Rating=5.0)
# Pandas(UserId=226, MovieId=1117, Rating=3.0)
# Pandas(UserId=896, MovieId=230, Rating=4.0)
# Pandas(UserId=537, MovieId=942, Rating=3.0)
# Pandas(UserId=747, MovieId=558, Rating=4.0)
# Pandas(UserId=90, MovieId=657, Rating=5.0)
# Pandas(UserId=683, MovieId=62, Rating=4.0)
# Pandas(UserId=883, MovieId=367, Rating=5.0)
# Pandas(UserId=486, MovieId=1171, Rating=3.0)
# Pandas(UserId=486, MovieId=319, Rating=3.0)
# Pandas(UserId=22, MovieId=684, Rating=3.0)
# Pandas(UserId=882, MovieId=196, Rating=4.0)
# Pandas(UserId=311, MovieId=210, Rating=5.0)
# Pandas(UserId=500, MovieId=425, Rating=4.0)
# Pandas(UserId=102, MovieId=635, Rating=2.0)
# Pandas(UserId=181, MovieId=1054, Rating=2.0)
# Pandas(UserId=372, MovieId=185, Rating=5.0)
# Pandas(UserId=495, MovieId=98, Rating=5.0)
# Pandas(UserId=853, MovieId=299, Rating=4.0)
# Pandas(UserId=537, MovieId=461, Rating=3.0)
# Pandas(UserId=600, MovieId=82, Rating=5.0)
# Pandas(UserId=735, MovieId=301, Rating=3.0)
# Pandas(UserId=943, MovieId=11, Rating=4.0)
# Pandas(UserId=838, MovieId=169, Rating=4.0)
# Pandas(UserId=178, MovieId=655, Rating=4.0)
# Pandas(UserId=492, MovieId=514, Rating=3.0)
# Pandas(UserId=70, MovieId=175, Rating=3.0)
# Pandas(UserId=451, MovieId=991, Rating=2.0)
# Pandas(UserId=438, MovieId=245, Rating=5.0)
# Pandas(UserId=796, MovieId=278, Rating=4.0)
# Pandas(UserId=318, MovieId=197, Rating=5.0)
# Pandas(UserId=174, MovieId=49, Rating=4.0)
# Pandas(UserId=933, MovieId=384, Rating=1.0)
# Pandas(UserId=504, MovieId=142, Rating=3.0)
# Pandas(UserId=886, MovieId=1489, Rating=1.0)
# Pandas(UserId=768, MovieId=272, Rating=5.0)
# Pandas(UserId=697, MovieId=683, Rating=1.0)
# Pandas(UserId=897, MovieId=71, Rating=5.0)
# Pandas(UserId=201, MovieId=1211, Rating=3.0)
# Pandas(UserId=346, MovieId=684, Rating=4.0)
# Pandas(UserId=1, MovieId=44, Rating=5.0)
# Pandas(UserId=708, MovieId=304, Rating=4.0)
# Pandas(UserId=332, MovieId=210, Rating=5.0)
# Pandas(UserId=650, MovieId=715, Rating=3.0)
# Pandas(UserId=642, MovieId=1076, Rating=2.0)
# Pandas(UserId=296, MovieId=628, Rating=5.0)
# Pandas(UserId=646, MovieId=319, Rating=3.0)
# Pandas(UserId=449, MovieId=410, Rating=3.0)
# Pandas(UserId=805, MovieId=469, Rating=4.0)
# Pandas(UserId=591, MovieId=381, Rating=4.0)
# Pandas(UserId=749, MovieId=157, Rating=3.0)
# Pandas(UserId=115, MovieId=8, Rating=5.0)
# Pandas(UserId=461, MovieId=304, Rating=4.0)
# Pandas(UserId=620, MovieId=418, Rating=3.0)
# Pandas(UserId=548, MovieId=525, Rating=5.0)
# Pandas(UserId=541, MovieId=83, Rating=5.0)
# Pandas(UserId=279, MovieId=12, Rating=2.0)
# Pandas(UserId=752, MovieId=321, Rating=3.0)
# Pandas(UserId=535, MovieId=59, Rating=3.0)
# Pandas(UserId=117, MovieId=98, Rating=4.0)
# Pandas(UserId=201, MovieId=1422, Rating=2.0)
# Pandas(UserId=492, MovieId=1147, Rating=1.0)
# Pandas(UserId=536, MovieId=86, Rating=3.0)
# Pandas(UserId=234, MovieId=151, Rating=3.0)
# Pandas(UserId=327, MovieId=484, Rating=3.0)
# Pandas(UserId=889, MovieId=269, Rating=4.0)
# Pandas(UserId=830, MovieId=294, Rating=3.0)
# Pandas(UserId=362, MovieId=347, Rating=5.0)
# Pandas(UserId=416, MovieId=330, Rating=3.0)
# Pandas(UserId=641, MovieId=192, Rating=4.0)
# Pandas(UserId=239, MovieId=479, Rating=5.0)
# Pandas(UserId=480, MovieId=100, Rating=4.0)
# Pandas(UserId=455, MovieId=475, Rating=4.0)
# Pandas(UserId=148, MovieId=509, Rating=5.0)
# Pandas(UserId=721, MovieId=357, Rating=5.0)
# Pandas(UserId=297, MovieId=73, Rating=2.0)
# Pandas(UserId=557, MovieId=875, Rating=4.0)
# Pandas(UserId=234, MovieId=431, Rating=3.0)
# Pandas(UserId=747, MovieId=318, Rating=5.0)
# Pandas(UserId=852, MovieId=820, Rating=4.0)
# Pandas(UserId=577, MovieId=823, Rating=3.0)
# Pandas(UserId=441, MovieId=259, Rating=3.0)
# Pandas(UserId=206, MovieId=359, Rating=1.0)
# Pandas(UserId=395, MovieId=258, Rating=4.0)
# Pandas(UserId=16, MovieId=404, Rating=5.0)
# Pandas(UserId=49, MovieId=1028, Rating=2.0)
# Pandas(UserId=896, MovieId=752, Rating=1.0)
# Pandas(UserId=897, MovieId=135, Rating=3.0)
# Pandas(UserId=693, MovieId=742, Rating=3.0)
# Pandas(UserId=804, MovieId=415, Rating=3.0)
# Pandas(UserId=167, MovieId=1200, Rating=4.0)
# Pandas(UserId=847, MovieId=501, Rating=3.0)
# Pandas(UserId=70, MovieId=260, Rating=2.0)
# Pandas(UserId=542, MovieId=210, Rating=3.0)
# Pandas(UserId=595, MovieId=762, Rating=4.0)
# Pandas(UserId=129, MovieId=1176, Rating=4.0)
# Pandas(UserId=533, MovieId=118, Rating=4.0)
# Pandas(UserId=26, MovieId=25, Rating=3.0)
# Pandas(UserId=94, MovieId=720, Rating=1.0)
# Pandas(UserId=417, MovieId=123, Rating=2.0)
# Pandas(UserId=822, MovieId=1110, Rating=4.0)
# Pandas(UserId=334, MovieId=333, Rating=4.0)
# Pandas(UserId=524, MovieId=4, Rating=4.0)
# Pandas(UserId=643, MovieId=219, Rating=5.0)
# Pandas(UserId=59, MovieId=659, Rating=3.0)
# Pandas(UserId=846, MovieId=218, Rating=4.0)
# Pandas(UserId=577, MovieId=720, Rating=4.0)
# Pandas(UserId=458, MovieId=980, Rating=5.0)
# Pandas(UserId=318, MovieId=1050, Rating=4.0)
# Pandas(UserId=891, MovieId=546, Rating=3.0)
# Pandas(UserId=222, MovieId=672, Rating=1.0)
# Pandas(UserId=31, MovieId=135, Rating=4.0)
# Pandas(UserId=370, MovieId=661, Rating=5.0)
# Pandas(UserId=416, MovieId=282, Rating=5.0)
# Pandas(UserId=655, MovieId=327, Rating=3.0)
# Pandas(UserId=405, MovieId=663, Rating=2.0)
# Pandas(UserId=920, MovieId=332, Rating=3.0)
# Pandas(UserId=660, MovieId=272, Rating=4.0)
# Pandas(UserId=151, MovieId=610, Rating=5.0)
# Pandas(UserId=495, MovieId=133, Rating=3.0)
# Pandas(UserId=708, MovieId=751, Rating=4.0)
# Pandas(UserId=627, MovieId=229, Rating=2.0)
# Pandas(UserId=63, MovieId=284, Rating=3.0)
# Pandas(UserId=555, MovieId=236, Rating=5.0)
# Pandas(UserId=688, MovieId=877, Rating=5.0)
# Pandas(UserId=533, MovieId=566, Rating=4.0)
# Pandas(UserId=897, MovieId=202, Rating=2.0)
# Pandas(UserId=776, MovieId=524, Rating=5.0)
# Pandas(UserId=450, MovieId=591, Rating=4.0)
# Pandas(UserId=426, MovieId=1020, Rating=4.0)
# Pandas(UserId=717, MovieId=130, Rating=2.0)
# Pandas(UserId=411, MovieId=172, Rating=5.0)
# Pandas(UserId=416, MovieId=550, Rating=4.0)
# Pandas(UserId=399, MovieId=57, Rating=4.0)
# Pandas(UserId=565, MovieId=640, Rating=4.0)
# Pandas(UserId=602, MovieId=300, Rating=3.0)
# Pandas(UserId=181, MovieId=1337, Rating=1.0)
# Pandas(UserId=642, MovieId=50, Rating=5.0)
# Pandas(UserId=719, MovieId=423, Rating=3.0)
# Pandas(UserId=416, MovieId=790, Rating=4.0)
# Pandas(UserId=767, MovieId=921, Rating=5.0)
# Pandas(UserId=280, MovieId=735, Rating=2.0)
# Pandas(UserId=731, MovieId=205, Rating=1.0)
# Pandas(UserId=562, MovieId=1, Rating=2.0)
# Pandas(UserId=833, MovieId=667, Rating=1.0)
# Pandas(UserId=851, MovieId=109, Rating=4.0)
# Pandas(UserId=271, MovieId=744, Rating=4.0)
# Pandas(UserId=555, MovieId=21, Rating=4.0)
# Pandas(UserId=211, MovieId=69, Rating=3.0)
# Pandas(UserId=830, MovieId=313, Rating=5.0)
# Pandas(UserId=334, MovieId=1020, Rating=4.0)
# Pandas(UserId=119, MovieId=689, Rating=4.0)
# Pandas(UserId=532, MovieId=679, Rating=5.0)
# Pandas(UserId=592, MovieId=182, Rating=5.0)
# Pandas(UserId=659, MovieId=195, Rating=4.0)
# Pandas(UserId=387, MovieId=79, Rating=4.0)
# Pandas(UserId=408, MovieId=288, Rating=4.0)
# Pandas(UserId=395, MovieId=255, Rating=3.0)
# Pandas(UserId=751, MovieId=631, Rating=5.0)
# Pandas(UserId=889, MovieId=203, Rating=2.0)
# Pandas(UserId=268, MovieId=2, Rating=2.0)
# Pandas(UserId=799, MovieId=289, Rating=3.0)
# Pandas(UserId=622, MovieId=298, Rating=4.0)
# Pandas(UserId=933, MovieId=470, Rating=4.0)
# Pandas(UserId=601, MovieId=39, Rating=1.0)
# Pandas(UserId=44, MovieId=237, Rating=3.0)
# Pandas(UserId=69, MovieId=117, Rating=4.0)
# Pandas(UserId=429, MovieId=762, Rating=4.0)
# Pandas(UserId=641, MovieId=558, Rating=5.0)
# Pandas(UserId=478, MovieId=231, Rating=1.0)
# Pandas(UserId=222, MovieId=473, Rating=1.0)
# Pandas(UserId=935, MovieId=274, Rating=5.0)
# Pandas(UserId=49, MovieId=38, Rating=1.0)
# Pandas(UserId=849, MovieId=625, Rating=5.0)
# Pandas(UserId=64, MovieId=385, Rating=4.0)
# Pandas(UserId=484, MovieId=422, Rating=3.0)
# Pandas(UserId=174, MovieId=368, Rating=1.0)
# Pandas(UserId=280, MovieId=68, Rating=3.0)
# Pandas(UserId=420, MovieId=179, Rating=5.0)
# Pandas(UserId=104, MovieId=628, Rating=4.0)
# Pandas(UserId=183, MovieId=50, Rating=2.0)
# Pandas(UserId=339, MovieId=302, Rating=4.0)
# Pandas(UserId=592, MovieId=655, Rating=5.0)
# Pandas(UserId=846, MovieId=72, Rating=4.0)
# Pandas(UserId=235, MovieId=285, Rating=4.0)
# Pandas(UserId=325, MovieId=208, Rating=3.0)
# Pandas(UserId=638, MovieId=385, Rating=5.0)
# Pandas(UserId=690, MovieId=66, Rating=3.0)
# Pandas(UserId=447, MovieId=200, Rating=3.0)
# Pandas(UserId=894, MovieId=350, Rating=3.0)
# Pandas(UserId=127, MovieId=343, Rating=5.0)
# Pandas(UserId=194, MovieId=546, Rating=3.0)
# Pandas(UserId=910, MovieId=137, Rating=3.0)
# Pandas(UserId=807, MovieId=142, Rating=3.0)
# Pandas(UserId=64, MovieId=273, Rating=2.0)
# Pandas(UserId=568, MovieId=179, Rating=2.0)
# Pandas(UserId=501, MovieId=288, Rating=4.0)
# Pandas(UserId=342, MovieId=156, Rating=4.0)
# Pandas(UserId=145, MovieId=449, Rating=3.0)
# Pandas(UserId=851, MovieId=895, Rating=3.0)
# ...
# Pandas(UserId=253, MovieId=96, Rating=5.0)
# Pandas(UserId=7, MovieId=546, Rating=4.0)
# Pandas(UserId=251, MovieId=147, Rating=3.0)
# Pandas(UserId=721, MovieId=681, Rating=3.0)
# Pandas(UserId=244, MovieId=1188, Rating=4.0)
# Pandas(UserId=508, MovieId=219, Rating=1.0)
# Pandas(UserId=900, MovieId=31, Rating=2.0)
# Pandas(UserId=95, MovieId=95, Rating=3.0)
# Pandas(UserId=225, MovieId=22, Rating=5.0)
# Pandas(UserId=694, MovieId=520, Rating=5.0)
# Pandas(UserId=393, MovieId=125, Rating=4.0)
# Pandas(UserId=521, MovieId=17, Rating=1.0)
# Pandas(UserId=276, MovieId=67, Rating=3.0)
# Pandas(UserId=930, MovieId=151, Rating=2.0)
# Pandas(UserId=592, MovieId=521, Rating=5.0)
# Pandas(UserId=894, MovieId=1009, Rating=4.0)
# Pandas(UserId=639, MovieId=356, Rating=2.0)
# Pandas(UserId=280, MovieId=11, Rating=5.0)
# Pandas(UserId=606, MovieId=530, Rating=4.0)
# Pandas(UserId=935, MovieId=15, Rating=5.0)
# Pandas(UserId=551, MovieId=66, Rating=2.0)
# Pandas(UserId=659, MovieId=172, Rating=3.0)
# Pandas(UserId=92, MovieId=202, Rating=3.0)
# Pandas(UserId=556, MovieId=496, Rating=5.0)
# Pandas(UserId=381, MovieId=49, Rating=2.0)
# Pandas(UserId=55, MovieId=144, Rating=5.0)
# Pandas(UserId=389, MovieId=486, Rating=4.0)
# Pandas(UserId=438, MovieId=148, Rating=5.0)
# Pandas(UserId=223, MovieId=322, Rating=4.0)
# Pandas(UserId=151, MovieId=1, Rating=5.0)
# Pandas(UserId=267, MovieId=554, Rating=3.0)
# Pandas(UserId=169, MovieId=181, Rating=5.0)
# Pandas(UserId=268, MovieId=238, Rating=3.0)
# Pandas(UserId=267, MovieId=216, Rating=4.0)
# Pandas(UserId=658, MovieId=511, Rating=4.0)
# Pandas(UserId=458, MovieId=582, Rating=1.0)
# Pandas(UserId=334, MovieId=209, Rating=3.0)
# Pandas(UserId=349, MovieId=100, Rating=4.0)
# Pandas(UserId=916, MovieId=1268, Rating=3.0)
# Pandas(UserId=649, MovieId=257, Rating=5.0)
# Pandas(UserId=932, MovieId=606, Rating=4.0)
# Pandas(UserId=388, MovieId=300, Rating=4.0)
# Pandas(UserId=427, MovieId=1296, Rating=5.0)
# Pandas(UserId=669, MovieId=12, Rating=5.0)
# Pandas(UserId=224, MovieId=258, Rating=3.0)
# Pandas(UserId=776, MovieId=182, Rating=3.0)
# Pandas(UserId=907, MovieId=25, Rating=5.0)
# Pandas(UserId=100, MovieId=328, Rating=4.0)
# Pandas(UserId=327, MovieId=204, Rating=4.0)
# Pandas(UserId=864, MovieId=194, Rating=4.0)
# Pandas(UserId=695, MovieId=343, Rating=4.0)
# Pandas(UserId=653, MovieId=197, Rating=3.0)
# Pandas(UserId=655, MovieId=233, Rating=3.0)
# Pandas(UserId=308, MovieId=634, Rating=4.0)
# Pandas(UserId=381, MovieId=120, Rating=1.0)
# Pandas(UserId=286, MovieId=411, Rating=2.0)
# Pandas(UserId=647, MovieId=134, Rating=4.0)
# Pandas(UserId=731, MovieId=127, Rating=4.0)
# Pandas(UserId=230, MovieId=234, Rating=4.0)
# Pandas(UserId=715, MovieId=95, Rating=4.0)
# Pandas(UserId=535, MovieId=44, Rating=4.0)
# Pandas(UserId=151, MovieId=210, Rating=4.0)
# Pandas(UserId=198, MovieId=820, Rating=1.0)
# Pandas(UserId=201, MovieId=134, Rating=4.0)
# Pandas(UserId=532, MovieId=147, Rating=4.0)
# Pandas(UserId=267, MovieId=214, Rating=4.0)
# Pandas(UserId=566, MovieId=8, Rating=4.0)
# Pandas(UserId=49, MovieId=423, Rating=2.0)
# Pandas(UserId=201, MovieId=505, Rating=3.0)
# Pandas(UserId=1, MovieId=252, Rating=2.0)
# Pandas(UserId=151, MovieId=168, Rating=5.0)
# Pandas(UserId=146, MovieId=307, Rating=3.0)
# Pandas(UserId=216, MovieId=298, Rating=5.0)
# Pandas(UserId=360, MovieId=69, Rating=3.0)
# Pandas(UserId=42, MovieId=467, Rating=3.0)
# Pandas(UserId=416, MovieId=761, Rating=4.0)
# Pandas(UserId=588, MovieId=934, Rating=4.0)
# Pandas(UserId=147, MovieId=269, Rating=4.0)
# Pandas(UserId=537, MovieId=990, Rating=2.0)
# Pandas(UserId=531, MovieId=892, Rating=3.0)
# Pandas(UserId=806, MovieId=14, Rating=3.0)
# Pandas(UserId=508, MovieId=209, Rating=5.0)
# Pandas(UserId=293, MovieId=582, Rating=4.0)
# Pandas(UserId=429, MovieId=161, Rating=3.0)
# Pandas(UserId=312, MovieId=121, Rating=3.0)
# Pandas(UserId=712, MovieId=172, Rating=5.0)
# Pandas(UserId=399, MovieId=550, Rating=3.0)
# Pandas(UserId=296, MovieId=659, Rating=5.0)
# Pandas(UserId=892, MovieId=288, Rating=4.0)
# Pandas(UserId=716, MovieId=160, Rating=2.0)
# Pandas(UserId=342, MovieId=975, Rating=2.0)
# Pandas(UserId=334, MovieId=405, Rating=3.0)
# Pandas(UserId=593, MovieId=366, Rating=4.0)
# Pandas(UserId=862, MovieId=472, Rating=5.0)
# Pandas(UserId=56, MovieId=423, Rating=5.0)
# Pandas(UserId=457, MovieId=588, Rating=5.0)
# Pandas(UserId=367, MovieId=333, Rating=4.0)
# Pandas(UserId=887, MovieId=318, Rating=5.0)
# Pandas(UserId=262, MovieId=1054, Rating=2.0)
# Pandas(UserId=117, MovieId=151, Rating=4.0)
# Pandas(UserId=198, MovieId=655, Rating=4.0)
# Pandas(UserId=7, MovieId=483, Rating=4.0)
# Pandas(UserId=207, MovieId=129, Rating=3.0)
# Pandas(UserId=844, MovieId=24, Rating=5.0)
# Pandas(UserId=341, MovieId=881, Rating=5.0)
# Pandas(UserId=933, MovieId=160, Rating=3.0)
# Pandas(UserId=298, MovieId=311, Rating=3.0)
# Pandas(UserId=551, MovieId=218, Rating=5.0)
# Pandas(UserId=844, MovieId=7, Rating=3.0)
# Pandas(UserId=305, MovieId=203, Rating=4.0)
# Pandas(UserId=13, MovieId=230, Rating=3.0)
# Pandas(UserId=821, MovieId=597, Rating=3.0)
# Pandas(UserId=568, MovieId=475, Rating=4.0)
# Pandas(UserId=387, MovieId=109, Rating=4.0)
# Pandas(UserId=643, MovieId=715, Rating=5.0)
# Pandas(UserId=154, MovieId=302, Rating=4.0)
# Pandas(UserId=638, MovieId=636, Rating=3.0)
# Pandas(UserId=747, MovieId=17, Rating=4.0)
# Pandas(UserId=201, MovieId=123, Rating=2.0)
# Pandas(UserId=500, MovieId=50, Rating=3.0)
# Pandas(UserId=782, MovieId=894, Rating=2.0)
# Pandas(UserId=682, MovieId=924, Rating=5.0)
# Pandas(UserId=488, MovieId=205, Rating=4.0)
# Pandas(UserId=203, MovieId=100, Rating=1.0)
# Pandas(UserId=279, MovieId=16, Rating=4.0)
# Pandas(UserId=533, MovieId=580, Rating=3.0)
# Pandas(UserId=152, MovieId=1053, Rating=5.0)
# Pandas(UserId=715, MovieId=367, Rating=3.0)
# Pandas(UserId=890, MovieId=1065, Rating=3.0)
# Pandas(UserId=323, MovieId=294, Rating=3.0)
# Pandas(UserId=843, MovieId=563, Rating=2.0)
# Pandas(UserId=559, MovieId=265, Rating=4.0)
# Pandas(UserId=450, MovieId=1020, Rating=4.0)
# Pandas(UserId=57, MovieId=1095, Rating=2.0)
# Pandas(UserId=468, MovieId=237, Rating=4.0)
# Pandas(UserId=192, MovieId=125, Rating=3.0)
# Pandas(UserId=909, MovieId=300, Rating=5.0)
# Pandas(UserId=804, MovieId=24, Rating=5.0)
# Pandas(UserId=880, MovieId=298, Rating=4.0)
# Pandas(UserId=457, MovieId=1012, Rating=4.0)
# Pandas(UserId=424, MovieId=681, Rating=3.0)
# Pandas(UserId=44, MovieId=151, Rating=4.0)
# Pandas(UserId=234, MovieId=173, Rating=3.0)
# Pandas(UserId=625, MovieId=181, Rating=4.0)
# Pandas(UserId=201, MovieId=1425, Rating=3.0)
# Pandas(UserId=334, MovieId=902, Rating=4.0)
# Pandas(UserId=326, MovieId=519, Rating=5.0)
# Pandas(UserId=311, MovieId=654, Rating=3.0)
# Pandas(UserId=896, MovieId=470, Rating=2.0)
# Pandas(UserId=270, MovieId=727, Rating=5.0)
# Pandas(UserId=880, MovieId=187, Rating=5.0)
# Pandas(UserId=571, MovieId=69, Rating=2.0)
# Pandas(UserId=17, MovieId=628, Rating=1.0)
# Pandas(UserId=255, MovieId=672, Rating=2.0)
# Pandas(UserId=145, MovieId=869, Rating=4.0)
# Pandas(UserId=337, MovieId=392, Rating=5.0)
# Pandas(UserId=608, MovieId=100, Rating=4.0)
# Pandas(UserId=881, MovieId=1089, Rating=1.0)
# Pandas(UserId=827, MovieId=272, Rating=4.0)
# Pandas(UserId=631, MovieId=346, Rating=4.0)
# Pandas(UserId=537, MovieId=47, Rating=4.0)
# Pandas(UserId=618, MovieId=729, Rating=3.0)
# Pandas(UserId=634, MovieId=125, Rating=4.0)
# Pandas(UserId=632, MovieId=720, Rating=3.0)
# Pandas(UserId=758, MovieId=211, Rating=4.0)
# Pandas(UserId=804, MovieId=68, Rating=3.0)
# Pandas(UserId=768, MovieId=100, Rating=5.0)
# Pandas(UserId=698, MovieId=1, Rating=4.0)
# Pandas(UserId=523, MovieId=289, Rating=4.0)
# Pandas(UserId=25, MovieId=419, Rating=4.0)
# Pandas(UserId=318, MovieId=63, Rating=3.0)
# Pandas(UserId=878, MovieId=699, Rating=1.0)
# Pandas(UserId=606, MovieId=1149, Rating=4.0)
# Pandas(UserId=297, MovieId=574, Rating=1.0)
# Pandas(UserId=919, MovieId=319, Rating=3.0)
# Pandas(UserId=345, MovieId=708, Rating=3.0)
# Pandas(UserId=307, MovieId=230, Rating=5.0)
# Pandas(UserId=92, MovieId=307, Rating=4.0)
# Pandas(UserId=20, MovieId=1, Rating=3.0)
# Pandas(UserId=655, MovieId=1167, Rating=3.0)
# Pandas(UserId=749, MovieId=969, Rating=4.0)
# Pandas(UserId=7, MovieId=423, Rating=5.0)
# Pandas(UserId=798, MovieId=231, Rating=2.0)
# Pandas(UserId=935, MovieId=284, Rating=4.0)
# Pandas(UserId=104, MovieId=333, Rating=2.0)
# Pandas(UserId=207, MovieId=826, Rating=2.0)
# Pandas(UserId=263, MovieId=1, Rating=5.0)
# Pandas(UserId=378, MovieId=280, Rating=2.0)
# Pandas(UserId=254, MovieId=699, Rating=3.0)
# Pandas(UserId=870, MovieId=505, Rating=4.0)
# Pandas(UserId=435, MovieId=154, Rating=4.0)
# Pandas(UserId=10, MovieId=133, Rating=5.0)
# Pandas(UserId=437, MovieId=191, Rating=4.0)
# Pandas(UserId=472, MovieId=577, Rating=3.0)
# Pandas(UserId=718, MovieId=273, Rating=3.0)
# Pandas(UserId=455, MovieId=204, Rating=4.0)
# Pandas(UserId=184, MovieId=1121, Rating=4.0)
# Pandas(UserId=585, MovieId=30, Rating=4.0)
# Pandas(UserId=943, MovieId=230, Rating=1.0)
# Pandas(UserId=96, MovieId=153, Rating=4.0)
# Pandas(UserId=660, MovieId=1074, Rating=1.0)
# Pandas(UserId=293, MovieId=17, Rating=2.0)
# Pandas(UserId=500, MovieId=735, Rating=4.0)
# Pandas(UserId=40, MovieId=259, Rating=2.0)
# Pandas(UserId=280, MovieId=232, Rating=3.0)
# Pandas(UserId=560, MovieId=50, Rating=5.0)
# Pandas(UserId=610, MovieId=484, Rating=3.0)
# Pandas(UserId=804, MovieId=153, Rating=4.0)
# Pandas(UserId=867, MovieId=258, Rating=3.0)
# Pandas(UserId=698, MovieId=153, Rating=2.0)
# Pandas(UserId=152, MovieId=117, Rating=4.0)
# Pandas(UserId=486, MovieId=304, Rating=3.0)
# Pandas(UserId=567, MovieId=487, Rating=4.0)
# Pandas(UserId=121, MovieId=25, Rating=5.0)
# Pandas(UserId=621, MovieId=55, Rating=5.0)
# Pandas(UserId=226, MovieId=258, Rating=5.0)
# Pandas(UserId=416, MovieId=420, Rating=3.0)
# Pandas(UserId=524, MovieId=402, Rating=2.0)
# Pandas(UserId=154, MovieId=515, Rating=4.0)
# Pandas(UserId=271, MovieId=81, Rating=3.0)
# Pandas(UserId=198, MovieId=690, Rating=3.0)
# Pandas(UserId=782, MovieId=301, Rating=3.0)
# Pandas(UserId=752, MovieId=589, Rating=4.0)
# Pandas(UserId=15, MovieId=405, Rating=2.0)
# Pandas(UserId=763, MovieId=1180, Rating=2.0)
# Pandas(UserId=196, MovieId=306, Rating=4.0)
# Pandas(UserId=765, MovieId=283, Rating=4.0)
# Pandas(UserId=882, MovieId=841, Rating=1.0)
# Pandas(UserId=234, MovieId=625, Rating=3.0)
# Pandas(UserId=504, MovieId=403, Rating=3.0)
# Pandas(UserId=276, MovieId=919, Rating=4.0)
# Pandas(UserId=363, MovieId=1007, Rating=5.0)
# Pandas(UserId=228, MovieId=56, Rating=2.0)
# Pandas(UserId=731, MovieId=15, Rating=4.0)
# Pandas(UserId=378, MovieId=792, Rating=4.0)
# Pandas(UserId=313, MovieId=203, Rating=5.0)
# Pandas(UserId=617, MovieId=1021, Rating=4.0)
# Pandas(UserId=533, MovieId=177, Rating=4.0)
# Pandas(UserId=631, MovieId=873, Rating=2.0)
# Pandas(UserId=716, MovieId=56, Rating=5.0)
# Pandas(UserId=642, MovieId=407, Rating=5.0)
# Pandas(UserId=330, MovieId=31, Rating=5.0)
# Pandas(UserId=805, MovieId=729, Rating=3.0)
# Pandas(UserId=597, MovieId=250, Rating=4.0)
# Pandas(UserId=288, MovieId=205, Rating=5.0)
# Pandas(UserId=487, MovieId=288, Rating=4.0)
# Pandas(UserId=41, MovieId=170, Rating=4.0)
# Pandas(UserId=103, MovieId=1089, Rating=1.0)
# Pandas(UserId=690, MovieId=663, Rating=4.0)
# Pandas(UserId=442, MovieId=436, Rating=3.0)
# Pandas(UserId=303, MovieId=518, Rating=4.0)
# Pandas(UserId=85, MovieId=53, Rating=3.0)
# Pandas(UserId=537, MovieId=399, Rating=2.0)
# Pandas(UserId=246, MovieId=402, Rating=3.0)
# Pandas(UserId=796, MovieId=810, Rating=3.0)
# Pandas(UserId=378, MovieId=739, Rating=4.0)
# Pandas(UserId=411, MovieId=655, Rating=4.0)
# Pandas(UserId=221, MovieId=346, Rating=5.0)
# Pandas(UserId=807, MovieId=403, Rating=4.0)
# Pandas(UserId=96, MovieId=484, Rating=5.0)
# Pandas(UserId=669, MovieId=517, Rating=3.0)
# Pandas(UserId=150, MovieId=100, Rating=2.0)
# Pandas(UserId=561, MovieId=1010, Rating=3.0)
# Pandas(UserId=541, MovieId=627, Rating=4.0)
# Pandas(UserId=44, MovieId=123, Rating=4.0)
# Pandas(UserId=524, MovieId=516, Rating=4.0)
# Pandas(UserId=280, MovieId=203, Rating=4.0)
# Pandas(UserId=666, MovieId=613, Rating=5.0)
# Pandas(UserId=445, MovieId=1008, Rating=1.0)
# Pandas(UserId=13, MovieId=747, Rating=4.0)
# Pandas(UserId=138, MovieId=111, Rating=4.0)
# Pandas(UserId=276, MovieId=9, Rating=5.0)
# Pandas(UserId=897, MovieId=294, Rating=3.0)
# Pandas(UserId=623, MovieId=216, Rating=4.0)
# Pandas(UserId=293, MovieId=64, Rating=5.0)
# Pandas(UserId=892, MovieId=67, Rating=4.0)
# Pandas(UserId=43, MovieId=321, Rating=3.0)
# Pandas(UserId=897, MovieId=436, Rating=4.0)
# Pandas(UserId=533, MovieId=215, Rating=4.0)
# Pandas(UserId=91, MovieId=498, Rating=3.0)
# Pandas(UserId=450, MovieId=65, Rating=3.0)
# Pandas(UserId=698, MovieId=526, Rating=2.0)
# Pandas(UserId=709, MovieId=56, Rating=5.0)
# Pandas(UserId=10, MovieId=479, Rating=5.0)
# Pandas(UserId=7, MovieId=623, Rating=3.0)
# Pandas(UserId=933, MovieId=184, Rating=1.0)
# Pandas(UserId=614, MovieId=546, Rating=1.0)
# Pandas(UserId=499, MovieId=100, Rating=4.0)
# Pandas(UserId=172, MovieId=1134, Rating=2.0)
# Pandas(UserId=339, MovieId=566, Rating=3.0)
# Pandas(UserId=347, MovieId=1291, Rating=1.0)
# Pandas(UserId=805, MovieId=419, Rating=4.0)
# Pandas(UserId=64, MovieId=194, Rating=5.0)
# Pandas(UserId=500, MovieId=831, Rating=3.0)
# Pandas(UserId=649, MovieId=471, Rating=5.0)
# Pandas(UserId=619, MovieId=96, Rating=5.0)
# Pandas(UserId=514, MovieId=301, Rating=4.0)
# Pandas(UserId=1, MovieId=184, Rating=4.0)
# Pandas(UserId=653, MovieId=157, Rating=5.0)
# Pandas(UserId=665, MovieId=181, Rating=4.0)
# Pandas(UserId=757, MovieId=270, Rating=3.0)
# Pandas(UserId=693, MovieId=88, Rating=3.0)
# Pandas(UserId=704, MovieId=611, Rating=3.0)
# Pandas(UserId=380, MovieId=631, Rating=4.0)
# Pandas(UserId=606, MovieId=472, Rating=4.0)
# Pandas(UserId=271, MovieId=148, Rating=3.0)
# Pandas(UserId=896, MovieId=25, Rating=3.0)
# Pandas(UserId=768, MovieId=237, Rating=4.0)
# Pandas(UserId=128, MovieId=729, Rating=2.0)
# Pandas(UserId=532, MovieId=1407, Rating=2.0)
# Pandas(UserId=128, MovieId=505, Rating=4.0)
# Pandas(UserId=505, MovieId=435, Rating=3.0)
# Pandas(UserId=457, MovieId=631, Rating=4.0)
# Pandas(UserId=850, MovieId=742, Rating=5.0)
# Pandas(UserId=450, MovieId=174, Rating=5.0)
# Pandas(UserId=406, MovieId=163, Rating=3.0)
# Pandas(UserId=655, MovieId=134, Rating=4.0)
# Pandas(UserId=665, MovieId=98, Rating=4.0)
# Pandas(UserId=290, MovieId=243, Rating=3.0)
# Pandas(UserId=201, MovieId=99, Rating=3.0)
# Pandas(UserId=892, MovieId=436, Rating=3.0)
# Pandas(UserId=586, MovieId=1218, Rating=5.0)
# Pandas(UserId=933, MovieId=183, Rating=4.0)
# Pandas(UserId=329, MovieId=11, Rating=3.0)
# Pandas(UserId=221, MovieId=1407, Rating=3.0)
# Pandas(UserId=903, MovieId=317, Rating=4.0)
# Pandas(UserId=79, MovieId=7, Rating=5.0)
# Pandas(UserId=429, MovieId=48, Rating=3.0)
# Pandas(UserId=774, MovieId=448, Rating=2.0)
# Pandas(UserId=624, MovieId=294, Rating=3.0)
# Pandas(UserId=795, MovieId=1199, Rating=3.0)
# Pandas(UserId=378, MovieId=70, Rating=4.0)
# Pandas(UserId=653, MovieId=771, Rating=2.0)
# Pandas(UserId=246, MovieId=133, Rating=3.0)
# Pandas(UserId=758, MovieId=441, Rating=3.0)
# Pandas(UserId=312, MovieId=188, Rating=3.0)
# Pandas(UserId=361, MovieId=156, Rating=4.0)
# Pandas(UserId=618, MovieId=939, Rating=2.0)
# Pandas(UserId=102, MovieId=210, Rating=3.0)
# Pandas(UserId=795, MovieId=473, Rating=2.0)
# Pandas(UserId=479, MovieId=22, Rating=4.0)
# Pandas(UserId=95, MovieId=649, Rating=4.0)
# Pandas(UserId=454, MovieId=504, Rating=2.0)
# Pandas(UserId=790, MovieId=1183, Rating=2.0)
# Pandas(UserId=530, MovieId=220, Rating=5.0)
# Pandas(UserId=144, MovieId=172, Rating=4.0)
# Pandas(UserId=921, MovieId=720, Rating=4.0)
# Pandas(UserId=833, MovieId=186, Rating=1.0)
# Pandas(UserId=601, MovieId=259, Rating=1.0)
# Pandas(UserId=576, MovieId=475, Rating=1.0)
# Pandas(UserId=102, MovieId=70, Rating=3.0)
# Pandas(UserId=847, MovieId=234, Rating=2.0)
# Pandas(UserId=637, MovieId=301, Rating=1.0)
# Pandas(UserId=170, MovieId=304, Rating=4.0)
# Pandas(UserId=416, MovieId=220, Rating=4.0)
# Pandas(UserId=473, MovieId=242, Rating=3.0)
# Pandas(UserId=409, MovieId=1093, Rating=2.0)
# Pandas(UserId=632, MovieId=318, Rating=5.0)
# Pandas(UserId=325, MovieId=319, Rating=3.0)
# Pandas(UserId=795, MovieId=546, Rating=3.0)
# Pandas(UserId=216, MovieId=231, Rating=2.0)
# Pandas(UserId=343, MovieId=276, Rating=5.0)
# Pandas(UserId=437, MovieId=475, Rating=3.0)
# Pandas(UserId=284, MovieId=322, Rating=3.0)
# Pandas(UserId=222, MovieId=200, Rating=3.0)

# %% [markdown]
# ### Train the BiVAE model
# - `k`: dimension of the latent space (i.e. the size of theta_u and beta_i).
# - `encoder_structure`: dimension(s) of hidden layer(s) of the user and item encoders.
# - `act_fn`: non-linear activation function used in the encoders.
# - `likelihood`: choice of the likelihood function being optimized.
# - `n_epochs`: number of passes through training data.
# - `batch_size`: size of mini-batches of data during training.
# - `learning_rate`: step size in the gradient update rules.

# %%
bivae = cornac.models.BiVAECF(k=latent_dim, encoder_structure=encoder_dims,
                             act_fn=act_func, likelihood=likelihood,
                             n_epochs=num_epochs, batch_size=batch_size,
                             learning_rate=learning_rate, seed=SEED,
                             use_gpu=torch.cuda.is_available(), verbose=True)

with Timer() as t:
    bivae.fit(train_set)
print('Took {} seconds for training'.format(t))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Took 26.3615 seconds for training

# %% [markdown]
# ### Prediction and Evaluation
# Cornac에서 제공하는 모든 추천 모델은 아이템의 평점을 예측하는 `rate()`와 유저에 대한 아이템 랭크 리스트`rank()` 메소드를 갖고 있다. 현재의 검증 스키마에서 예측을 위해 `predict()`와 `predict_ranking()` 함수를 사용한다.

# %%
with Timer() as t:
    all_predictions = predict_ranking(bivae, train, usercol='UserId', itemcol='MovieId', remove_seen=True)
print('Took {} seconds for prediction'.format(t))
# Out:
# Took 0.6089 seconds for prediction

# %%
eval_map = map_at_k(test, all_predictions, col_user='UserId', col_item='MovieId', col_rating='Rating', col_prediction='prediction', k=TOP_k)
eval_ndcg = ndcg_at_k(test, all_predictions, col_user='UserId', col_item='MovieId', col_rating='Rating', col_prediction='prediction', k=TOP_k)
eval_precision = precision_at_k(test, all_predictions, col_user='UserId', col_item='MovieId', col_rating='Rating', col_prediction='prediction', k=TOP_k)
eval_recall = recall_at_k(test, all_predictions, col_user='UserId', col_item='MovieId', col_rating='Rating', col_prediction='prediction', k=TOP_k)

print("MAP:\t%f" % eval_map,
      "NDCG:\t%f" % eval_ndcg,
      "Precision@K:\t%f" % eval_precision,
      "Recall@K:\t%f" % eval_recall, sep='\n')
# Out:
# MAP:	0.142060
# NDCG:	0.465813
# Precision@K:	0.404671
# Recall@K:	0.222637

# %%
# Record results with papermill for tests
sb.glue("map", eval_map)
sb.glue("ndcg", eval_ndcg)
sb.glue("precision", eval_precision)
sb.glue("recall", eval_recall)
# Out:
#        UserId  MovieId  Rating
# 75721     877      381     4.0
# 80184     815      602     3.0
# 19864      94      431     4.0
# 76699     416      875     2.0
# 92991     500      182     2.0
# ...       ...      ...     ...
# 21271     399      684     3.0
# 34014     222      580     3.0
# 81355     551      162     5.0
# 65720     803      988     1.0
# 11627      72      177     4.0
#
# [25000 rows x 3 columns]
